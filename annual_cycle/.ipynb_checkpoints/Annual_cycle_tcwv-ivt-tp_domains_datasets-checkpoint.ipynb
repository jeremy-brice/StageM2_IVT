# %%
import sys
sys.path.insert(1, '/home/bricej/MyPythonLibrary/StageM2_IVT/library/')
import domain
from domain import *
from climbas import *
import numpy as np
import xarray as xr
import pandas as pd
from netCDF4 import Dataset
from scipy import stats
import scipy.stats as stats
import matplotlib.pyplot as plt

# %% [markdown]
# # Period

# %%
iyear = 1960
fyear = 2025
variables = ['tcwv', 'ivt']
domains = ['HMA','HK','SL','TP','CH','SEH']

# %% [markdown]
# # TCWV & IVT Data

# %%
var_dict = {}

files = {'tcwv': 'tcwv_monthly_era5_1940-2025_NH_025x025.nc',
        'ivt': 'ivt_monthly_era5_1940-2025_MA_025x025.nc'}

path = '/bettik/PROJECTS/pr-regional-climate/bricej/era5/monthly/'

for var in variables:
    var_dict[var] = {}
    var_data = xr.open_dataset(path + files[var])[var]

    var_data = var_data.rename({'valid_time': 'time'})
    var_data = var_data.rename({'longitude': 'lon'})
    var_data = var_data.rename({'latitude': 'lat'})

    if var == 'tcwv':    
        # pour alléger le dossier 
        var_data = var_data.drop_vars(['number','expver'], errors='ignore')  # les variables inutiles
        var_data.attrs = {}  # les atributs pas utiles pour les calculs
    
    var_data = var_data.sel(time=slice(str(iyear),str(fyear)))
    
    for domain in domains:
            var_dict[var][domain] = field_dom(var_data,domain)

# %%
var_dict
# Out:
# {'tcwv': {'HMA': <xarray.DataArray 'tcwv' (time: 792, lat: 101, lon: 201)> Size: 64MB
#   [16078392 values with dtype=float32]
#   Coordinates:
#     * time     (time) datetime64[ns] 6kB 1960-01-01 1960-02-01 ... 2025-12-01
#     * lat      (lat) float64 808B 45.0 44.75 44.5 44.25 ... 20.75 20.5 20.25 20.0
#     * lon      (lon) float64 2kB 60.0 60.25 60.5 60.75 ... 109.2 109.5 109.8 110.0,
#   'HK': <xarray.DataArray 'tcwv' (time: 792, lat: 29, lon: 49)> Size: 5MB
#   [1125432 values with dtype=float32]
#   Coordinates:
#     * time     (time) datetime64[ns] 6kB 1960-01-01 1960-02-01 ... 2025-12-01
#     * lat      (lat) float64 232B 41.0 40.75 40.5 40.25 ... 34.75 34.5 34.25 34.0
#     * lon      (lon) float64 392B 64.0 64.25 64.5 64.75 ... 75.25 75.5 75.75 76.0,
#   'SL': <xarray.DataArray 'tcwv' (time: 792, lat: 29, lon: 17)> Size: 2MB
#   [390456 values with dtype=float32]
#   Coordinates:
#     * time     (time) datetime64[ns] 6kB 1960-01-01 1960-02-01 ... 2025-12-01
#     * lat      (lat) float64 232B 36.0 35.75 35.5 35.25 ... 29.75 29.5 29.25 29.0
#     * lon      (lon) float64 136B 76.0 76.25 76.5 76.75 ... 79.25 79.5 79.75 80.0,
#   'TP': <xarray.DataArray 'tcwv' (time: 792, lat: 31, lon: 89)> Size: 9MB
#   [2185128 values with dtype=float32]
#   Coordinates:
#     * time     (time) datetime64[ns] 6kB 1960-01-01 1960-02-01 ... 2025-12-01
#     * lat      (lat) float64 248B 38.0 37.75 37.5 37.25 ... 31.25 31.0 30.75 30.5
#     * lon      (lon) float64 712B 80.0 80.25 80.5 80.75 ... 101.5 101.8 102.0,
#   'CH': <xarray.DataArray 'tcwv' (time: 792, lat: 31, lon: 47)> Size: 5MB
#   [1153944 values with dtype=float32]
#   Coordinates:
#     * time     (time) datetime64[ns] 6kB 1960-01-01 1960-02-01 ... 2025-12-01
#     * lat      (lat) float64 248B 30.5 30.25 30.0 29.75 ... 23.75 23.5 23.25 23.0
#     * lon      (lon) float64 376B 80.0 80.25 80.5 80.75 ... 90.75 91.0 91.25 91.5,
#   'SEH': <xarray.DataArray 'tcwv' (time: 792, lat: 41, lon: 75)> Size: 10MB
#   [2435400 values with dtype=float32]
#   Coordinates:
#     * time     (time) datetime64[ns] 6kB 1960-01-01 1960-02-01 ... 2025-12-01
#     * lat      (lat) float64 328B 30.0 29.75 29.5 29.25 ... 20.75 20.5 20.25 20.0
#     * lon      (lon) float64 600B 91.5 91.75 92.0 92.25 ... 109.5 109.8 110.0},
#  'ivt': {'HMA': <xarray.DataArray 'ivt' (time: 792, lat: 101, lon: 201)> Size: 64MB
#   [16078392 values with dtype=float32]
#   Coordinates:
#     * time     (time) datetime64[ns] 6kB 1960-01-16 1960-02-15 ... 2025-12-16
#     * lon      (lon) float64 2kB 60.0 60.25 60.5 60.75 ... 109.2 109.5 109.8 110.0
#     * lat      (lat) float64 808B 45.0 44.75 44.5 44.25 ... 20.75 20.5 20.25 20.0,
#   'HK': <xarray.DataArray 'ivt' (time: 792, lat: 29, lon: 49)> Size: 5MB
#   [1125432 values with dtype=float32]
#   Coordinates:
#     * time     (time) datetime64[ns] 6kB 1960-01-16 1960-02-15 ... 2025-12-16
#     * lon      (lon) float64 392B 64.0 64.25 64.5 64.75 ... 75.25 75.5 75.75 76.0
#     * lat      (lat) float64 232B 41.0 40.75 40.5 40.25 ... 34.75 34.5 34.25 34.0,
#   'SL': <xarray.DataArray 'ivt' (time: 792, lat: 29, lon: 17)> Size: 2MB
#   [390456 values with dtype=float32]
#   Coordinates:
#     * time     (time) datetime64[ns] 6kB 1960-01-16 1960-02-15 ... 2025-12-16
#     * lon      (lon) float64 136B 76.0 76.25 76.5 76.75 ... 79.25 79.5 79.75 80.0
#     * lat      (lat) float64 232B 36.0 35.75 35.5 35.25 ... 29.75 29.5 29.25 29.0,
#   'TP': <xarray.DataArray 'ivt' (time: 792, lat: 31, lon: 89)> Size: 9MB
#   [2185128 values with dtype=float32]
#   Coordinates:
#     * time     (time) datetime64[ns] 6kB 1960-01-16 1960-02-15 ... 2025-12-16
#     * lon      (lon) float64 712B 80.0 80.25 80.5 80.75 ... 101.5 101.8 102.0
#     * lat      (lat) float64 248B 38.0 37.75 37.5 37.25 ... 31.25 31.0 30.75 30.5,
#   'CH': <xarray.DataArray 'ivt' (time: 792, lat: 31, lon: 47)> Size: 5MB
#   [1153944 values with dtype=float32]
#   Coordinates:
#     * time     (time) datetime64[ns] 6kB 1960-01-16 1960-02-15 ... 2025-12-16
#     * lon      (lon) float64 376B 80.0 80.25 80.5 80.75 ... 90.75 91.0 91.25 91.5
#     * lat      (lat) float64 248B 30.5 30.25 30.0 29.75 ... 23.75 23.5 23.25 23.0,
#   'SEH': <xarray.DataArray 'ivt' (time: 792, lat: 41, lon: 75)> Size: 10MB
#   [2435400 values with dtype=float32]
#   Coordinates:
#     * time     (time) datetime64[ns] 6kB 1960-01-16 1960-02-15 ... 2025-12-16
#     * lon      (lon) float64 600B 91.5 91.75 92.0 92.25 ... 109.5 109.8 110.0
#     * lat      (lat) float64 328B 30.0 29.75 29.5 29.25 ... 20.75 20.5 20.25 20.0}}

# %% [markdown]
# # MONTHLY MEAN DATASETS DOMAINS

# %%
var_mean_dict = {}

for var in variables:
    var_mean_dict[var]={}
    print(var)
    for domain in domains:
        var_mean_dict[var][domain] = var_dict[var][domain].groupby('time.month').mean('time', skipna=True)
        var_mean_dict[var][domain] = var_mean_dict[var][domain].mean(dim=['lat','lon'], skipna=True)
        print(domain)
# Out:
# tcwv
# HMA
# HK
# SL
# TP
# CH
# SEH
# ivt
# HMA
# HK
# SL
# TP
# CH
# SEH

# %%
months = ['Jan','Feb','Mar','Apr','May','Jun','Jul','Aug','Sep','Oct','Nov','Dec']
unite = {'tcwv': 'kg m⁻²',
        'ivt': 'kg m⁻¹ s⁻¹'}
colors = {'tcwv': 'blue', 
          'ivt': 'green'}

fig, axes = plt.subplots(3, 2, figsize=(16,10))
axes = axes.flatten()

handles_all = []
labels_all = []

for i, dom in enumerate(domains):

    ax = axes[i]
    ax2 = ax.twinx()

    # --- TCWV
    da_tcwv = var_mean_dict['tcwv'][dom]
    l1, = ax.plot(
        da_tcwv['month'], da_tcwv.values,
        marker='o', linestyle=':', color=colors['tcwv'],
        label=f'TCWV ({unite["tcwv"]})', linewidth=2
    )

    # --- IVT
    da_ivt = var_mean_dict['ivt'][dom]
    l2, = ax2.plot(
        da_ivt['month'], da_ivt.values,
        marker='o', linestyle=':', color=colors['ivt'],
        label=f'IVT ({unite["ivt"]})', linewidth=2
    )

    # récupérer légende sur la première figure
    if i == 0:
        handles_all.extend([l1, l2])
        labels_all.extend([l1.get_label(), l2.get_label()])

    # --- reste inchangé
    ax.set_title(dom, fontsize=16, weight="bold")
    ax.set_xticks(range(1,13))

    if i in [4, 5]:
        ax.set_xticklabels(months, rotation=45, fontsize=16)
    else:
        ax.tick_params(labelbottom=False)

    if i in [0, 2, 4]:
        ax.set_ylabel('TCWV (kg m⁻²)', fontsize=12)
    if i in [1, 3, 5]:
        ax2.set_ylabel('IVT (kg m⁻¹ s⁻¹)', fontsize=12)

    ax.grid(True, linestyle='--', alpha=0.5)

# --- légende
fig.legend(
    handles_all,
    labels_all,
    loc='lower center',
    bbox_to_anchor=(0.5, -0.04),
    ncol=2,
    fontsize=16,
    frameon=True
)

fig.suptitle(f'Annual Cycle TCWV & IVT ({iyear}-{fyear})', fontsize=16, weight='bold')

plt.tight_layout(rect=[0,0.05,1,1])
plt.subplots_adjust(hspace=0.2, wspace=0.1)
plt.show()

# %% [markdown]
# # Comparing with ERA5 and CHIRPS precipitation

# %%
iyear = 1960
fyear = 2025
models = ['CHIRPS','ERA5']
domains = ['HMA','HK','SL','TP','CH','SEH']

# %%
tp_datasets = {}

files = {'CHIRPS': 'tp_HMA_1981-2025_CHIRPS.nc',
        'ERA5': 'tp_HMA_1940-2025_ERA5.nc'}

path = '/bettik/PROJECTS/pr-regional-climate/bricej/tp_datasets/'


for model in models:
    tp_datasets[model] = {}
    tp_model = xr.open_dataset(path + files[model])['tp']
    if model=='ERA5':
        tp_model=tp_model.sel(time=slice(str(iyear),str(fyear)))
    else:
            tp_model=tp_model.sel(time=slice(str(1981),str(2024)))
    for domain in domains:
        tp_datasets[model][domain] = field_dom(tp_model,domain)

# %%
tp_mean_dict = {}

for model in models:
    tp_mean_dict[model]={}
    print(model)
    for domain in domains:
        tp_mean_dict[model][domain] = tp_datasets[model][domain].groupby('time.month').mean('time', skipna=True)
        tp_mean_dict[model][domain] = tp_mean_dict[model][domain].mean(dim=['lat','lon'], skipna=True)
        print(domain)
# Out:
# CHIRPS
# HMA
# HK
# SL
# TP
# CH
# SEH
# ERA5
# HMA
# HK
# SL
# TP
# CH
# SEH

# %%
months = ['Jan','Feb','Mar','Apr','May','Jun','Jul','Aug','Sep','Oct','Nov','Dec']
resolutions = {'CHIRPS': '0.05°x0.05°',
               'ERA5': '0.25°x0.25°'}
period = {'CHIRPS': '1981-2024',
               'ERA5': '1960-2025'}
colors = {'CHIRPS': 'red',
          'ERA5': 'orange'}

fig, axes = plt.subplots(3, 2, figsize=(16,10))
axes = axes.flatten()

for i, dom in enumerate(domains):

    ax = axes[i]

    for model in models:
        da = tp_mean_dict[model][dom]
        ax.plot(da['month'], da.values, marker='o', linestyle=':', color=colors[model], label=f'{model} ({resolutions[model]}) ({period[model]})', linewidth=2)

    ax.set_title(dom, fontsize=16, weight="bold")
    ax.set_xticks(range(1,13))
    
    if i in [0, 2, 4]:  # colonne gauche
        ax.set_ylabel('tp (mm month⁻¹)', fontsize=12)
    if i in [4, 5]:  # ligne du bas
        ax.set_xticklabels(months, rotation=45, fontsize=16)
    if i in [0,1,2,3]:
        ax.tick_params(labelbottom=False)
    
    ax.grid(True, linestyle='--', alpha=0.5)

handles, labels = axes[0].get_legend_handles_labels()
fig.legend(
    handles,
    labels,
    loc='lower center',
    bbox_to_anchor=(0.5, -0.04),
    ncol=3,
    fontsize=16,
    frameon=True
)
fig.suptitle(f'Annual Cycle Precipitation', fontsize=16, weight='bold')

plt.tight_layout(rect=[0,0.05,1,1])
plt.show()

# %%
fig, axes = plt.subplots(3, 2, figsize=(16,10))
axes = axes.flatten()

handles_all = []
labels_all = []

for i, dom in enumerate(domains):

    ax = axes[i]
    ax2 = ax.twinx()  # axe droit

    # --- PRECIP (axe gauche)
    for model in models:
        da = tp_mean_dict[model][dom]
        l, = ax.plot(
            da['month'], da.values,
            marker='o', linestyle=':',
            color=colors[model],
            label=f'tp {model} ({resolutions[model]}) ({period[model]})',
            linewidth=2
        )

        # stocker une seule fois
        if i == 0:
            handles_all.append(l)
            labels_all.append(l.get_label())

    # --- TCWV (axe droit)
    da_tcwv = var_mean_dict['tcwv'][dom]
    l_tcwv, = ax2.plot(
        da_tcwv['month'], da_tcwv.values,
        marker='o', linestyle=':',
        color='blue',
        label=f'TCWV (kg m⁻²) ({period[model]})',
        linewidth=2
    )

    if i == 0:
        handles_all.append(l_tcwv)
        labels_all.append(l_tcwv.get_label())

    # --- TITRES
    ax.set_title(dom, fontsize=16, weight="bold")
    ax.set_xticks(range(1,13))

    # --- X ticks
    if i in [4, 5]:
        ax.set_xticklabels(months, rotation=45, fontsize=16)
    else:
        ax.tick_params(labelbottom=False)

    # --- Y labels
    if i in [0, 2, 4]:
        ax.set_ylabel('tp (mm month⁻¹)', fontsize=12)
    if i in [1, 3, 5]:
        ax2.set_ylabel('TCWV (kg m⁻²)', fontsize=12)

    ax.grid(True, linestyle='--', alpha=0.5)

# --- LEGENDE
fig.legend(
    handles_all,
    labels_all,
    loc='lower center',
    bbox_to_anchor=(0.5, -0.04),
    ncol=3,
    fontsize=16,
    frameon=True
)

fig.suptitle('Annual Cycle Precipitation & TCWV', fontsize=16, weight='bold')

plt.tight_layout(rect=[0,0.05,1,1])
plt.subplots_adjust(hspace=0.3, wspace=0.2)

plt.show()

# %%
fig, axes = plt.subplots(3, 2, figsize=(16,10))
axes = axes.flatten()

handles_all = []
labels_all = []

for i, dom in enumerate(domains):

    ax = axes[i]
    ax2 = ax.twinx()  # axe droit

    # --- PRECIP (axe gauche)
    for model in models:
        da = tp_mean_dict[model][dom]
        l, = ax.plot(
            da['month'], da.values,
            marker='o', linestyle=':',
            color=colors[model],
            label=f'tp {model} ({resolutions[model]}) ({period[model]})',
            linewidth=2
        )

        # stocker une seule fois
        if i == 0:
            handles_all.append(l)
            labels_all.append(l.get_label())

    # --- IVT (axe droit)
    da_tcwv = var_mean_dict['ivt'][dom]
    l_tcwv, = ax2.plot(
        da_tcwv['month'], da_tcwv.values,
        marker='o', linestyle=':',
        color='green',
        label=f'IVT (kg m⁻¹ s⁻¹) ({period[model]})',
        linewidth=2
    )

    if i == 0:
        handles_all.append(l_tcwv)
        labels_all.append(l_tcwv.get_label())

    # --- TITRES
    ax.set_title(dom, fontsize=16, weight="bold")
    ax.set_xticks(range(1,13))

    # --- X ticks
    if i in [4, 5]:
        ax.set_xticklabels(months, rotation=45, fontsize=16)
    else:
        ax.tick_params(labelbottom=False)

    # --- Y labels
    if i in [0, 2, 4]:
        ax.set_ylabel('tp (mm month⁻¹)', fontsize=12)
    if i in [1, 3, 5]:
        ax2.set_ylabel('IVT (kg m⁻¹ s⁻¹)', fontsize=12)

    ax.grid(True, linestyle='--', alpha=0.5)

# --- LEGENDE
fig.legend(
    handles_all,
    labels_all,
    loc='lower center',
    bbox_to_anchor=(0.5, -0.04),
    ncol=3,
    fontsize=16,
    frameon=True
)

fig.suptitle('Annual Cycle Precipitation & IVT', fontsize=16, weight='bold')

plt.tight_layout(rect=[0,0.05,1,1])
plt.subplots_adjust(hspace=0.3, wspace=0.2)

plt.show()
