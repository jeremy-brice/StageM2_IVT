# %%
import sys
sys.path.insert(1, '/home/bricej/MyPythonLibrary/StageM2_IVT/library/')
import domain
from domain import *
from climbas import *
import numpy as np
import xarray as xr
import pandas as pd
from netCDF4 import Dataset
from scipy import stats
import scipy.stats as stats
import matplotlib.pyplot as plt
import matplotlib.cm as cm
import matplotlib.colors as mcolors

# %% [markdown]
# # Period & Domain

# %%
iyear=1960
fyear=2024
nx=10;ny=10
dom='GRp'
dom_NST = 'GRi'
year_NST = '2014'

# %% [markdown]
# # SF & RF & TF Data

# %%
RF = xr.open_mfdataset(f'/bettik/PROJECTS/pr-regional-climate/santolam/MARout_post/{dom}/spin2/work/monthly/RF_monsum_MARv3.14_ER5_spin2_{dom}_*.nc',
                       combine="by_coords")['RF']
RF = RF.rename({'TIME': 'time'})
RF = RF[:,ny:-ny,nx:-nx].sel(time=slice(f"{iyear}-01-01", f"{fyear}-12-31"))

SF = xr.open_mfdataset(f'/bettik/PROJECTS/pr-regional-climate/santolam/MARout_post/{dom}/spin2/work/monthly/SF_monsum_MARv3.14_ER5_spin2_{dom}_*.nc',
                       combine="by_coords")['SF']
SF = SF.rename({'TIME': 'time'})
SF = SF[:,ny:-ny,nx:-nx].sel(time=slice(f"{iyear}-01-01", f"{fyear}-12-31"))


#Compute Total Rainfall
TF = RF + SF

# %% [markdown]
# # Annual Mean

# %%
TF_mean = TF.groupby('time.year').mean('time', skipna=True)
TF_mean = TF_mean.mean(dim=['Y','X'], skipna=True)

SF_mean = SF.groupby('time.year').mean('time', skipna=True)
SF_mean = SF_mean.mean(dim=['Y','X'], skipna=True)

RF_mean = RF.groupby('time.year').mean('time', skipna=True)
RF_mean = RF_mean.mean(dim=['Y','X'], skipna=True)

R_mean = RF_mean / SF_mean * 100

# %% [markdown]
# # Trends

# %%
slope_RF, intercept_RF, r_value_RF, p_value_RF, std_err_RF = stats.linregress(RF_mean['year'].values, RF_mean.values)
trend_RF = intercept_RF + slope_RF * RF_mean['year'].values

slope_SF, intercept_SF, r_value_SF, p_value_SF, std_err_SF = stats.linregress(SF_mean['year'].values, SF_mean.values)
trend_SF = intercept_SF + slope_SF * SF_mean['year'].values

slope_TF, intercept_TF, r_value_TF, p_value_TF, std_err_TF = stats.linregress(TF_mean['year'].values, TF_mean.values)
trend_TF = intercept_TF + slope_TF * TF_mean['year'].values

slope_R, intercept_R, r_value_R, p_value_R, std_err_R = stats.linregress(R_mean['year'].values, R_mean.values)
trend_R = intercept_R + slope_R * R_mean['year'].values

# %% [markdown]
# # Statistics

# %%
mean_RF = np.mean(RF_mean.values)
std_RF = np.std(RF_mean.values)
min_RF = np.min(RF_mean.values)
max_RF = np.max(RF_mean.values)

mean_SF = np.mean(SF_mean.values)
std_SF = np.std(SF_mean.values)
min_SF = np.min(SF_mean.values)
max_SF = np.max(SF_mean.values)

mean_TF = np.mean(TF_mean.values)
std_TF = np.std(TF_mean.values)
min_TF = np.min(TF_mean.values)
max_TF = np.max(TF_mean.values)

mean_R = np.mean(R_mean.values)
std_R = np.std(R_mean.values)
min_R = np.min(R_mean.values)
max_R = np.max(R_mean.values)

# %%
print(f'RF : {slope_RF * 10:.2f} mm / year / decade (p={p_value_RF:.3f}) ({(slope_RF*10)/mean_RF*100:.1f} %/decade) (std={std_RF/mean_RF*100:.1f} %)\n')
print(f'SF : {slope_SF * 10:.2f} mm / year / decade (p={p_value_SF:.3f}) ({(slope_SF*10)/mean_SF*100:.1f} %/decade) (std={std_SF/mean_SF*100:.1f} %)\n')
print(f'TF : {slope_TF * 10:.2f} mm / year / decade (p={p_value_TF:.3f}) ({(slope_TF*10)/mean_TF*100:.1f} %/decade) (std={std_TF/mean_TF*100:.1f} %)\n')
print(f'R : {slope_R * 10:.2f} % / decade (p={p_value_R:.3f}) (std={std_R:.1f} %)\n')

fig, ax = plt.subplots(figsize=(8,5))

ax2 = ax.twinx()  # axe droit
# mettre l'axe droit en red
ax2.tick_params(axis='y', colors='red')
ax2.yaxis.label.set_color('red')
ax2.spines['right'].set_color('red')

ax.plot(RF_mean['year'].values, RF_mean.values, color='royalblue', label='RF', linewidth=2)
ax.plot(RF_mean['year'].values, trend_RF, color='royalblue', linewidth=1, linestyle='--')

ax.plot(SF_mean['year'].values, SF_mean.values, color='violet', label='SF', linewidth=2)
ax.plot(SF_mean['year'].values, trend_SF, color='violet', linewidth=1, linestyle='--')

ax.plot(TF_mean['year'].values, TF_mean.values, color='green', label='TF', linewidth=2)
ax.plot(TF_mean['year'].values, trend_TF, color='green', linewidth=1, linestyle='--')

ax2.plot(R_mean['year'].values, R_mean.values, color='red', label='R', linewidth=1)
ax2.plot(R_mean['year'].values, trend_R, color='red', linewidth=1, linestyle='--')

ax.grid(True, linestyle='--', alpha=0.5, zorder=0)
ax.set_xlabel('year')
ax.set_ylabel('Precipitation (mm/month)')
ax2.set_ylabel('R (%)')

# --- legend
handles1, labels1 = ax.get_legend_handles_labels()
handles2, labels2 = ax2.get_legend_handles_labels()
ax.legend(handles1 + handles2, labels1 + labels2, fontsize=9)

plt.tight_layout()
plt.show()
# Out:
# RF : 0.09 mm / year / decade (p=0.046) (4.2 %/decade) (std=31.8 %)
#
# SF : -0.12 mm / year / decade (p=0.446) (-0.7 %/decade) (std=13.9 %)
#
# TF : -0.03 mm / year / decade (p=0.869) (-0.2 %/decade) (std=14.6 %)
#
# R : 0.63 % / decade (p=0.004) (std=3.3 %)

# %% [markdown]
# # Evolution of freezing level height (FLH)

# %%
FLH = pd.read_csv(f'/bettik/PROJECTS/pr-regional-climate/bricej/MAR/FLH_monthly_timeseries_MAR_1960-2024_GRp.csv', parse_dates=["time"])
FLH = FLH.set_index('time')

# %%
# Annual mean over study period for FLH computed by MAR 
FLH_mean = FLH.groupby(FLH.index.year)['FLH'].mean().reset_index()
FLH_mean.columns = ['year', 'FLH']

#trend
slope_FLH, intercept_FLH, r_value_FLH, p_value_FLH, std_err_FLH = stats.linregress(FLH_mean['year'].values, FLH_mean['FLH'].values)
trend_FLH = intercept_FLH + slope_FLH * FLH_mean['year'].values

#statistics
mean_FLH = np.mean(FLH_mean['FLH'].values)
std_FLH = np.std(FLH_mean['FLH'].values)
min_FLH = np.min(FLH_mean['FLH'].values)
max_FLH = np.max(FLH_mean['FLH'].values)

# %%
print(f'RF : {slope_FLH * 10:.2f} m / decade (p={p_value_FLH:.3f}) ({(slope_FLH*10)/mean_FLH*100:.1f} %/decade) (std={std_FLH/mean_FLH*100:.1f} %)\n')

fig, ax = plt.subplots(figsize=(8,5))

ax.plot(FLH_mean['year'].values, FLH_mean['FLH'].values, color='orange', label='FLH', linewidth=2)
ax.plot(FLH_mean['year'].values, trend_FLH, color='orange', linewidth=1, linestyle='--')

ax.grid(True, linestyle='--', alpha=0.5, zorder=0)
ax.set_xlabel('year')
ax.set_ylabel('FLH (m)')

# --- legend
ax.legend(fontsize=9)

plt.tight_layout()
plt.show()
# Out:
# RF : 10.62 m / decade (p=0.364) (0.3 %/decade) (std=5.2 %)

# %% [markdown]
# # Monthly timeseries

# %%
RF_monthly_timeseries = {}
SF_monthly_timeseries = {}
TF_monthly_timeseries = {}
R_monthly_timeseries = {}

for i in np.arange(1,13):
    
    # Selection of a single month through the all period
    RF_month = RF.sel(time=RF.time.dt.month == i)
    SF_month = SF.sel(time=SF.time.dt.month == i)
    TF_month = TF.sel(time=RF.time.dt.month == i)
    
    # Monthly mean for month i
    RF_monthly = RF_month.groupby('time.year').mean('time', skipna=True)
    RF_monthly = RF_monthly.mean(dim=['Y','X'], skipna=True)
    
    SF_monthly = SF_month.groupby('time.year').mean('time', skipna=True)
    SF_monthly = SF_monthly.mean(dim=['Y','X'], skipna=True)
    
    TF_monthly = TF_month.groupby('time.year').mean('time', skipna=True)
    TF_monthly = TF_monthly.mean(dim=['Y','X'], skipna=True)
    
    R_monthly = RF_monthly / SF_monthly * 100

    RF_monthly_timeseries[i] = RF_monthly
    SF_monthly_timeseries[i] = SF_monthly
    TF_monthly_timeseries[i] = TF_monthly
    R_monthly_timeseries[i] = R_monthly

# %% [markdown]
# # Monthly trends

# %%
RF_monthly_trends = {}
SF_monthly_trends = {}
TF_monthly_trends = {}
R_monthly_trends = {}

RF_monthly_trends_stats = {}
SF_monthly_trends_stats = {}
TF_monthly_trends_stats = {}
R_monthly_trends_stats = {}

for i in np.arange(1,13):

    slope_month_RF, intercept_month_RF, r_value_month_RF, p_value_month_RF, std_err_month_RF = stats.linregress(RF_monthly_timeseries[i]['year'].values, RF_monthly_timeseries[i].values)
    trend_month_RF = intercept_month_RF + slope_month_RF * RF_monthly_timeseries[i]['year'].values
    
    slope_month_SF, intercept_month_SF, r_value_month_SF, p_value_month_SF, std_err_month_SF = stats.linregress(SF_monthly_timeseries[i]['year'].values, SF_monthly_timeseries[i].values)
    trend_month_SF = intercept_month_SF + slope_month_SF * SF_monthly_timeseries[i]['year'].values
    
    slope_month_TF, intercept_month_TF, r_value_month_TF, p_value_month_TF, std_err_month_TF = stats.linregress(TF_monthly_timeseries[i]['year'].values, TF_monthly_timeseries[i].values)
    trend_month_TF = intercept_month_TF + slope_month_TF * TF_monthly_timeseries[i]['year'].values
    
    slope_month_R, intercept_month_R, r_value_month_R, p_value_month_R, std_err_month_R = stats.linregress(R_monthly_timeseries[i]['year'].values, R_monthly_timeseries[i].values)
    trend_month_R = intercept_month_R + slope_month_R * R_monthly_timeseries[i]['year'].values

    RF_monthly_trends_stats[i] = [slope_month_RF, intercept_month_RF, r_value_month_RF, p_value_month_RF, std_err_month_RF]
    SF_monthly_trends_stats[i] = [slope_month_SF, intercept_month_SF, r_value_month_SF, p_value_month_SF, std_err_month_SF]
    TF_monthly_trends_stats[i] = [slope_month_TF, intercept_month_TF, r_value_month_TF, p_value_month_TF, std_err_month_TF]
    R_monthly_trends_stats[i] = [slope_month_R, intercept_month_R, r_value_month_R, p_value_month_R, std_err_month_R]

    RF_monthly_trends[i] = trend_month_RF
    SF_monthly_trends[i] = trend_month_SF
    TF_monthly_trends[i] = trend_month_TF
    R_monthly_trends[i] = trend_month_R

# %% [markdown]
# # Monthly statistics

# %%
RF_monthly_stats = {}
SF_monthly_stats = {}
TF_monthly_stats = {}
R_monthly_stats = {}

for i in np.arange(1,13):

    mean_month_RF = np.mean(RF_monthly_timeseries[i].values)
    std_month_RF = np.std(RF_monthly_timeseries[i].values)
    min_month_RF = np.min(RF_monthly_timeseries[i].values)
    max_month_RF = np.max(RF_monthly_timeseries[i].values)
    
    mean_month_SF = np.mean(SF_monthly_timeseries[i].values)
    std_month_SF = np.std(SF_monthly_timeseries[i].values)
    min_month_SF = np.min(SF_monthly_timeseries[i].values)
    max_month_SF = np.max(SF_monthly_timeseries[i].values)
    
    mean_month_TF = np.mean(TF_monthly_timeseries[i].values)
    std_month_TF = np.std(TF_monthly_timeseries[i].values)
    min_month_TF = np.min(TF_monthly_timeseries[i].values)
    max_month_TF = np.max(TF_monthly_timeseries[i].values)
    
    mean_month_R = np.mean(R_monthly_timeseries[i].values)
    std_month_R = np.std(R_monthly_timeseries[i].values)
    min_month_R = np.min(R_monthly_timeseries[i].values)
    max_month_R = np.max(R_monthly_timeseries[i].values)

    RF_monthly_stats[i] = [mean_month_RF, std_month_RF, min_month_RF, max_month_RF]
    SF_monthly_stats[i] = [mean_month_SF, std_month_SF, min_month_SF, max_month_SF]
    TF_monthly_stats[i] = [mean_month_TF, std_month_TF, min_month_TF, max_month_TF]
    R_monthly_stats[i] = [mean_month_R, std_month_R, min_month_R, max_month_R]

# %%
months = ['Jan','Feb','Mar','Apr','May','Jun','Jul','Aug','Sep','Oct','Nov','Dec']

#====================== statistics tab ==============================================================================

def bold_sig(val, p):
    if p < 0.05:
        return 'font-weight: bold'
    return ''

#========= RF ================
print('==================================================== RF =================================================')

table = pd.DataFrame(index=months, columns=['slope (mm/month/decade)', 'slope (%/decade)', 'std (mm/month)', 'std (%)'])
pvals = pd.DataFrame(index=months, columns=['slope (mm/month/decade)', 'slope (%/decade)', 'std (mm/month)', 'std (%)'])

for i in np.arange(1,13):

    RF_slope = RF_monthly_trends_stats[i][0] * 10
    RF_pval  = RF_monthly_trends_stats[i][3]
    RF_slope_percentage = RF_slope /  RF_monthly_stats[i][0] * 100
    RF_std = RF_monthly_stats[i][1]
    RF_std_percentage = RF_std /  RF_monthly_stats[i][0] * 100

    table.loc[months[i-1], 'slope (mm/month/decade)'] = RF_slope
    table.loc[months[i-1], 'slope (%/decade)'] = RF_slope_percentage
    table.loc[months[i-1], 'std (mm/month)'] = RF_std
    table.loc[months[i-1], 'std (%)'] = RF_std_percentage

    
    pvals.loc[months[i-1], 'slope (mm/month/decade)'] = RF_pval
    pvals.loc[months[i-1], 'slope (%/decade)'] = RF_pval

formats = {
    'slope (mm/month/decade)': "{:.2f}",
    'slope (%/decade)': "{:.1f}",
    'std (mm/month)': "{:.2f}",      
    'std (%)': "{:.1f}"
}

styled_table = table.style.apply(
    lambda x: [bold_sig(v, pvals.loc[x.name, col]) for col, v in x.items()],
    axis=1
).format(formats, na_rep='-')

display(styled_table)

#========= SF ================
print('==================================================== SF =================================================')

table = pd.DataFrame(index=months, columns=['slope (mm/month/decade)', 'slope (%/decade)', 'std (mm/month)', 'std (%)'])
pvals = pd.DataFrame(index=months, columns=['slope (mm/month/decade)', 'slope (%/decade)', 'std (mm/month)', 'std (%)'])

for i in np.arange(1,13):

    SF_slope = SF_monthly_trends_stats[i][0] * 10
    SF_pval  = SF_monthly_trends_stats[i][3]
    SF_slope_percentage = SF_slope /  SF_monthly_stats[i][0] * 100
    SF_std = SF_monthly_stats[i][1]
    SF_std_percentage = SF_std /  SF_monthly_stats[i][0] * 100

    table.loc[months[i-1], 'slope (mm/month/decade)'] = SF_slope
    table.loc[months[i-1], 'slope (%/decade)'] = SF_slope_percentage
    table.loc[months[i-1], 'std (mm/month)'] = SF_std
    table.loc[months[i-1], 'std (%)'] = SF_std_percentage

    
    pvals.loc[months[i-1], 'slope (mm/month/decade)'] = SF_pval
    pvals.loc[months[i-1], 'slope (%/decade)'] = SF_pval

formats = {
    'slope (mm/month/decade)': "{:.2f}",
    'slope (%/decade)': "{:.1f}",
    'std (mm/month)': "{:.2f}",      
    'std (%)': "{:.1f}"
}

styled_table = table.style.apply(
    lambda x: [bold_sig(v, pvals.loc[x.name, col]) for col, v in x.items()],
    axis=1
).format(formats, na_rep='-')

display(styled_table)

#========= TF ================
print('==================================================== TF =================================================')

table = pd.DataFrame(index=months, columns=['slope (mm/month/decade)', 'slope (%/decade)', 'std (mm/month)', 'std (%)'])
pvals = pd.DataFrame(index=months, columns=['slope (mm/month/decade)', 'slope (%/decade)', 'std (mm/month)', 'std (%)'])

for i in np.arange(1,13):

    TF_slope = TF_monthly_trends_stats[i][0] * 10
    TF_pval  = TF_monthly_trends_stats[i][3]
    TF_slope_percentage = TF_slope /  TF_monthly_stats[i][0] * 100
    TF_std = TF_monthly_stats[i][1]
    TF_std_percentage = TF_std /  TF_monthly_stats[i][0] * 100

    table.loc[months[i-1], 'slope (mm/month/decade)'] = TF_slope
    table.loc[months[i-1], 'slope (%/decade)'] = TF_slope_percentage
    table.loc[months[i-1], 'std (mm/month)'] = TF_std
    table.loc[months[i-1], 'std (%)'] = TF_std_percentage

    
    pvals.loc[months[i-1], 'slope (mm/month/decade)'] = TF_pval
    pvals.loc[months[i-1], 'slope (%/decade)'] = TF_pval

formats = {
    'slope (mm/month/decade)': "{:.2f}",
    'slope (%/decade)': "{:.1f}",
    'std (mm/month)': "{:.2f}",      
    'std (%)': "{:.1f}"
}

styled_table = table.style.apply(
    lambda x: [bold_sig(v, pvals.loc[x.name, col]) for col, v in x.items()],
    axis=1
).format(formats, na_rep='-')

display(styled_table)

#========= R ================
print('==================================================== R =================================================')

table = pd.DataFrame(index=months, columns=['slope (%/decade)', 'std (%)'])
pvals = pd.DataFrame(index=months, columns=['slope (%/decade)', 'std (%)'])

for i in np.arange(1,13):

    R_slope = R_monthly_trends_stats[i][0] * 10
    R_pval  = R_monthly_trends_stats[i][3]
    R_std = R_monthly_stats[i][1]

    table.loc[months[i-1], 'slope (%/decade)'] = R_slope
    table.loc[months[i-1], 'std (%)'] = R_std
    
    pvals.loc[months[i-1], 'slope (%/decade)'] = R_pval

formats = {
    'slope (%/decade)': "{:.2f}",
    'std (%)': "{:.2f}",      
}

styled_table = table.style.apply(
    lambda x: [bold_sig(v, pvals.loc[x.name, col]) for col, v in x.items()],
    axis=1
).format(formats, na_rep='-')

display(styled_table)

#======================== plot ============================================================================================

fig, axes = plt.subplots(6, 2, figsize=(16,20))
axes = axes.flatten()

for i, ax in enumerate(axes):
    
    ax2 = ax.twinx()  # axe droit
    # mettre l'axe droit en red
    ax2.tick_params(axis='y', colors='red')
    ax2.yaxis.label.set_color('red')
    ax2.spines['right'].set_color('red')
    
    ax.plot(RF_monthly_timeseries[i+1]['year'].values, RF_monthly_timeseries[i+1].values, color='royalblue', label='RF', linewidth=2)
    ax.plot(RF_monthly_timeseries[i+1]['year'].values, RF_monthly_trends[i+1], color='royalblue', linewidth=1, linestyle='--')
    
    ax.plot(SF_monthly_timeseries[i+1]['year'].values, SF_monthly_timeseries[i+1].values, color='violet', label='SF', linewidth=2)
    ax.plot(SF_monthly_timeseries[i+1]['year'].values, SF_monthly_trends[i+1], color='violet', linewidth=1, linestyle='--')
    
    ax.plot(TF_monthly_timeseries[i+1]['year'].values, TF_monthly_timeseries[i+1].values, color='green', label='TF', linewidth=2)
    ax.plot(TF_monthly_timeseries[i+1]['year'].values, TF_monthly_trends[i+1], color='green', linewidth=1, linestyle='--')
    
    ax2.plot(R_monthly_timeseries[i+1]['year'].values, R_monthly_timeseries[i+1].values, color='red', label='R', linewidth=1)
    ax2.plot(R_monthly_timeseries[i+1]['year'].values, R_monthly_trends[i+1], color='red', linewidth=1, linestyle='--')

    ax.set_title(months[i], fontsize=16, weight="bold")
    
    if i in [0, 2, 4, 6, 8, 10]:  # colonne gauche
        ax.set_ylabel('Precipitation (mm/month)', fontsize=12)

    if i in [1, 3, 5, 7, 9, 11]:  # colonne droite
        ax2.set_ylabel('R (%)', fontsize=12)
        
    if i in [10, 11]:  # ligne du bas
        ax.set_xlabel('year', fontsize=12)
    else:
        ax.tick_params(labelbottom=False)
    
    ax.grid(True, linestyle='--', alpha=0.5, zorder=0)
    
# --- legend
handles, labels = axes[0].get_legend_handles_labels()
fig.legend(
    handles,
    labels,
    loc='lower center',
    bbox_to_anchor=(0.5, -0.04),
    ncol=3,
    fontsize=16,
    frameon=True
)
    
plt.tight_layout()
plt.show()
# Out:
# ==================================================== RF =================================================
# <style type="text/css">
# #T_a176d_row5_col0, #T_a176d_row5_col1, #T_a176d_row7_col0, #T_a176d_row7_col1 {
#   font-weight: bold;
# }
# </style>
# <table id="T_a176d">
#   <thead>
#     <tr>
#       <th class="blank level0" >&nbsp;</th>
#       <th id="T_a176d_level0_col0" class="col_heading level0 col0" >slope (mm/month/decade)</th>
#       <th id="T_a176d_level0_col1" class="col_heading level0 col1" >slope (%/decade)</th>
#       <th id="T_a176d_level0_col2" class="col_heading level0 col2" >std (mm/month)</th>
#       <th id="T_a176d_level0_col3" class="col_heading level0 col3" >std (%)</th>
#     </tr>
#   </thead>
#   <tbody>
#     <tr>
#       <th id="T_a176d_level0_row0" class="row_heading level0 row0" >Jan</th>
#       <td id="T_a176d_row0_col0" class="data row0 col0" >0.02</td>
#       <td id="T_a176d_row0_col1" class="data row0 col1" >13.7</td>
#       <td id="T_a176d_row0_col2" class="data row0 col2" >0.16</td>
#       <td id="T_a176d_row0_col3" class="data row0 col3" >136.2</td>
#     </tr>
#     <tr>
#       <th id="T_a176d_level0_row1" class="row_heading level0 row1" >Feb</th>
#       <td id="T_a176d_row1_col0" class="data row1 col0" >0.03</td>
#       <td id="T_a176d_row1_col1" class="data row1 col1" >5.8</td>
#       <td id="T_a176d_row1_col2" class="data row1 col2" >0.47</td>
#       <td id="T_a176d_row1_col3" class="data row1 col3" >89.9</td>
#     </tr>
#     <tr>
#       <th id="T_a176d_level0_row2" class="row_heading level0 row2" >Mar</th>
#       <td id="T_a176d_row2_col0" class="data row2 col0" >-0.02</td>
#       <td id="T_a176d_row2_col1" class="data row2 col1" >-0.8</td>
#       <td id="T_a176d_row2_col2" class="data row2 col2" >1.32</td>
#       <td id="T_a176d_row2_col3" class="data row2 col3" >65.0</td>
#     </tr>
#     <tr>
#       <th id="T_a176d_level0_row3" class="row_heading level0 row3" >Apr</th>
#       <td id="T_a176d_row3_col0" class="data row3 col0" >-0.22</td>
#       <td id="T_a176d_row3_col1" class="data row3 col1" >-5.2</td>
#       <td id="T_a176d_row3_col2" class="data row3 col2" >2.35</td>
#       <td id="T_a176d_row3_col3" class="data row3 col3" >54.8</td>
#     </tr>
#     <tr>
#       <th id="T_a176d_level0_row4" class="row_heading level0 row4" >May</th>
#       <td id="T_a176d_row4_col0" class="data row4 col0" >-0.00</td>
#       <td id="T_a176d_row4_col1" class="data row4 col1" >-0.1</td>
#       <td id="T_a176d_row4_col2" class="data row4 col2" >3.01</td>
#       <td id="T_a176d_row4_col3" class="data row4 col3" >53.5</td>
#     </tr>
#     <tr>
#       <th id="T_a176d_level0_row5" class="row_heading level0 row5" >Jun</th>
#       <td id="T_a176d_row5_col0" class="data row5 col0" >0.46</td>
#       <td id="T_a176d_row5_col1" class="data row5 col1" >12.3</td>
#       <td id="T_a176d_row5_col2" class="data row5 col2" >2.45</td>
#       <td id="T_a176d_row5_col3" class="data row5 col3" >65.8</td>
#     </tr>
#     <tr>
#       <th id="T_a176d_level0_row6" class="row_heading level0 row6" >Jul</th>
#       <td id="T_a176d_row6_col0" class="data row6 col0" >0.27</td>
#       <td id="T_a176d_row6_col1" class="data row6 col1" >7.6</td>
#       <td id="T_a176d_row6_col2" class="data row6 col2" >2.78</td>
#       <td id="T_a176d_row6_col3" class="data row6 col3" >77.2</td>
#     </tr>
#     <tr>
#       <th id="T_a176d_level0_row7" class="row_heading level0 row7" >Aug</th>
#       <td id="T_a176d_row7_col0" class="data row7 col0" >0.42</td>
#       <td id="T_a176d_row7_col1" class="data row7 col1" >15.3</td>
#       <td id="T_a176d_row7_col2" class="data row7 col2" >2.15</td>
#       <td id="T_a176d_row7_col3" class="data row7 col3" >78.6</td>
#     </tr>
#     <tr>
#       <th id="T_a176d_level0_row8" class="row_heading level0 row8" >Sep</th>
#       <td id="T_a176d_row8_col0" class="data row8 col0" >0.06</td>
#       <td id="T_a176d_row8_col1" class="data row8 col1" >5.8</td>
#       <td id="T_a176d_row8_col2" class="data row8 col2" >0.78</td>
#       <td id="T_a176d_row8_col3" class="data row8 col3" >72.5</td>
#     </tr>
#     <tr>
#       <th id="T_a176d_level0_row9" class="row_heading level0 row9" >Oct</th>
#       <td id="T_a176d_row9_col0" class="data row9 col0" >-0.01</td>
#       <td id="T_a176d_row9_col1" class="data row9 col1" >-1.1</td>
#       <td id="T_a176d_row9_col2" class="data row9 col2" >1.02</td>
#       <td id="T_a176d_row9_col3" class="data row9 col3" >109.6</td>
#     </tr>
#     <tr>
#       <th id="T_a176d_level0_row10" class="row_heading level0 row10" >Nov</th>
#       <td id="T_a176d_row10_col0" class="data row10 col0" >0.09</td>
#       <td id="T_a176d_row10_col1" class="data row10 col1" >12.4</td>
#       <td id="T_a176d_row10_col2" class="data row10 col2" >0.74</td>
#       <td id="T_a176d_row10_col3" class="data row10 col3" >104.4</td>
#     </tr>
#     <tr>
#       <th id="T_a176d_level0_row11" class="row_heading level0 row11" >Dec</th>
#       <td id="T_a176d_row11_col0" class="data row11 col0" >-0.02</td>
#       <td id="T_a176d_row11_col1" class="data row11 col1" >-6.4</td>
#       <td id="T_a176d_row11_col2" class="data row11 col2" >0.39</td>
#       <td id="T_a176d_row11_col3" class="data row11 col3" >141.3</td>
#     </tr>
#   </tbody>
# </table>
# ==================================================== SF =================================================
# <style type="text/css">
# #T_467d4_row5_col0, #T_467d4_row5_col1 {
#   font-weight: bold;
# }
# </style>
# <table id="T_467d4">
#   <thead>
#     <tr>
#       <th class="blank level0" >&nbsp;</th>
#       <th id="T_467d4_level0_col0" class="col_heading level0 col0" >slope (mm/month/decade)</th>
#       <th id="T_467d4_level0_col1" class="col_heading level0 col1" >slope (%/decade)</th>
#       <th id="T_467d4_level0_col2" class="col_heading level0 col2" >std (mm/month)</th>
#       <th id="T_467d4_level0_col3" class="col_heading level0 col3" >std (%)</th>
#     </tr>
#   </thead>
#   <tbody>
#     <tr>
#       <th id="T_467d4_level0_row0" class="row_heading level0 row0" >Jan</th>
#       <td id="T_467d4_row0_col0" class="data row0 col0" >0.10</td>
#       <td id="T_467d4_row0_col1" class="data row0 col1" >0.5</td>
#       <td id="T_467d4_row0_col2" class="data row0 col2" >7.33</td>
#       <td id="T_467d4_row0_col3" class="data row0 col3" >41.2</td>
#     </tr>
#     <tr>
#       <th id="T_467d4_level0_row1" class="row_heading level0 row1" >Feb</th>
#       <td id="T_467d4_row1_col0" class="data row1 col0" >0.28</td>
#       <td id="T_467d4_row1_col1" class="data row1 col1" >1.1</td>
#       <td id="T_467d4_row1_col2" class="data row1 col2" >8.68</td>
#       <td id="T_467d4_row1_col3" class="data row1 col3" >35.3</td>
#     </tr>
#     <tr>
#       <th id="T_467d4_level0_row2" class="row_heading level0 row2" >Mar</th>
#       <td id="T_467d4_row2_col0" class="data row2 col0" >-1.31</td>
#       <td id="T_467d4_row2_col1" class="data row2 col1" >-4.1</td>
#       <td id="T_467d4_row2_col2" class="data row2 col2" >11.16</td>
#       <td id="T_467d4_row2_col3" class="data row2 col3" >35.2</td>
#     </tr>
#     <tr>
#       <th id="T_467d4_level0_row3" class="row_heading level0 row3" >Apr</th>
#       <td id="T_467d4_row3_col0" class="data row3 col0" >-0.67</td>
#       <td id="T_467d4_row3_col1" class="data row3 col1" >-2.3</td>
#       <td id="T_467d4_row3_col2" class="data row3 col2" >9.78</td>
#       <td id="T_467d4_row3_col3" class="data row3 col3" >33.0</td>
#     </tr>
#     <tr>
#       <th id="T_467d4_level0_row4" class="row_heading level0 row4" >May</th>
#       <td id="T_467d4_row4_col0" class="data row4 col0" >-0.94</td>
#       <td id="T_467d4_row4_col1" class="data row4 col1" >-3.4</td>
#       <td id="T_467d4_row4_col2" class="data row4 col2" >10.44</td>
#       <td id="T_467d4_row4_col3" class="data row4 col3" >38.3</td>
#     </tr>
#     <tr>
#       <th id="T_467d4_level0_row5" class="row_heading level0 row5" >Jun</th>
#       <td id="T_467d4_row5_col0" class="data row5 col0" >1.07</td>
#       <td id="T_467d4_row5_col1" class="data row5 col1" >7.6</td>
#       <td id="T_467d4_row5_col2" class="data row5 col2" >7.63</td>
#       <td id="T_467d4_row5_col3" class="data row5 col3" >54.4</td>
#     </tr>
#     <tr>
#       <th id="T_467d4_level0_row6" class="row_heading level0 row6" >Jul</th>
#       <td id="T_467d4_row6_col0" class="data row6 col0" >-0.21</td>
#       <td id="T_467d4_row6_col1" class="data row6 col1" >-3.6</td>
#       <td id="T_467d4_row6_col2" class="data row6 col2" >4.97</td>
#       <td id="T_467d4_row6_col3" class="data row6 col3" >83.0</td>
#     </tr>
#     <tr>
#       <th id="T_467d4_level0_row7" class="row_heading level0 row7" >Aug</th>
#       <td id="T_467d4_row7_col0" class="data row7 col0" >0.29</td>
#       <td id="T_467d4_row7_col1" class="data row7 col1" >7.7</td>
#       <td id="T_467d4_row7_col2" class="data row7 col2" >2.97</td>
#       <td id="T_467d4_row7_col3" class="data row7 col3" >78.4</td>
#     </tr>
#     <tr>
#       <th id="T_467d4_level0_row8" class="row_heading level0 row8" >Sep</th>
#       <td id="T_467d4_row8_col0" class="data row8 col0" >-0.03</td>
#       <td id="T_467d4_row8_col1" class="data row8 col1" >-0.5</td>
#       <td id="T_467d4_row8_col2" class="data row8 col2" >3.49</td>
#       <td id="T_467d4_row8_col3" class="data row8 col3" >66.5</td>
#     </tr>
#     <tr>
#       <th id="T_467d4_level0_row9" class="row_heading level0 row9" >Oct</th>
#       <td id="T_467d4_row9_col0" class="data row9 col0" >-0.14</td>
#       <td id="T_467d4_row9_col1" class="data row9 col1" >-1.2</td>
#       <td id="T_467d4_row9_col2" class="data row9 col2" >7.34</td>
#       <td id="T_467d4_row9_col3" class="data row9 col3" >60.4</td>
#     </tr>
#     <tr>
#       <th id="T_467d4_level0_row10" class="row_heading level0 row10" >Nov</th>
#       <td id="T_467d4_row10_col0" class="data row10 col0" >0.22</td>
#       <td id="T_467d4_row10_col1" class="data row10 col1" >1.5</td>
#       <td id="T_467d4_row10_col2" class="data row10 col2" >8.21</td>
#       <td id="T_467d4_row10_col3" class="data row10 col3" >53.0</td>
#     </tr>
#     <tr>
#       <th id="T_467d4_level0_row11" class="row_heading level0 row11" >Dec</th>
#       <td id="T_467d4_row11_col0" class="data row11 col0" >-0.10</td>
#       <td id="T_467d4_row11_col1" class="data row11 col1" >-0.7</td>
#       <td id="T_467d4_row11_col2" class="data row11 col2" >8.37</td>
#       <td id="T_467d4_row11_col3" class="data row11 col3" >52.4</td>
#     </tr>
#   </tbody>
# </table>
# ==================================================== TF =================================================
# <style type="text/css">
# #T_6879f_row5_col0, #T_6879f_row5_col1, #T_6879f_row7_col0, #T_6879f_row7_col1 {
#   font-weight: bold;
# }
# </style>
# <table id="T_6879f">
#   <thead>
#     <tr>
#       <th class="blank level0" >&nbsp;</th>
#       <th id="T_6879f_level0_col0" class="col_heading level0 col0" >slope (mm/month/decade)</th>
#       <th id="T_6879f_level0_col1" class="col_heading level0 col1" >slope (%/decade)</th>
#       <th id="T_6879f_level0_col2" class="col_heading level0 col2" >std (mm/month)</th>
#       <th id="T_6879f_level0_col3" class="col_heading level0 col3" >std (%)</th>
#     </tr>
#   </thead>
#   <tbody>
#     <tr>
#       <th id="T_6879f_level0_row0" class="row_heading level0 row0" >Jan</th>
#       <td id="T_6879f_row0_col0" class="data row0 col0" >0.11</td>
#       <td id="T_6879f_row0_col1" class="data row0 col1" >0.6</td>
#       <td id="T_6879f_row0_col2" class="data row0 col2" >7.39</td>
#       <td id="T_6879f_row0_col3" class="data row0 col3" >41.2</td>
#     </tr>
#     <tr>
#       <th id="T_6879f_level0_row1" class="row_heading level0 row1" >Feb</th>
#       <td id="T_6879f_row1_col0" class="data row1 col0" >0.31</td>
#       <td id="T_6879f_row1_col1" class="data row1 col1" >1.2</td>
#       <td id="T_6879f_row1_col2" class="data row1 col2" >8.88</td>
#       <td id="T_6879f_row1_col3" class="data row1 col3" >35.4</td>
#     </tr>
#     <tr>
#       <th id="T_6879f_level0_row2" class="row_heading level0 row2" >Mar</th>
#       <td id="T_6879f_row2_col0" class="data row2 col0" >-1.32</td>
#       <td id="T_6879f_row2_col1" class="data row2 col1" >-3.9</td>
#       <td id="T_6879f_row2_col2" class="data row2 col2" >11.92</td>
#       <td id="T_6879f_row2_col3" class="data row2 col3" >35.3</td>
#     </tr>
#     <tr>
#       <th id="T_6879f_level0_row3" class="row_heading level0 row3" >Apr</th>
#       <td id="T_6879f_row3_col0" class="data row3 col0" >-0.90</td>
#       <td id="T_6879f_row3_col1" class="data row3 col1" >-2.6</td>
#       <td id="T_6879f_row3_col2" class="data row3 col2" >11.26</td>
#       <td id="T_6879f_row3_col3" class="data row3 col3" >33.2</td>
#     </tr>
#     <tr>
#       <th id="T_6879f_level0_row4" class="row_heading level0 row4" >May</th>
#       <td id="T_6879f_row4_col0" class="data row4 col0" >-0.94</td>
#       <td id="T_6879f_row4_col1" class="data row4 col1" >-2.9</td>
#       <td id="T_6879f_row4_col2" class="data row4 col2" >12.46</td>
#       <td id="T_6879f_row4_col3" class="data row4 col3" >37.9</td>
#     </tr>
#     <tr>
#       <th id="T_6879f_level0_row5" class="row_heading level0 row5" >Jun</th>
#       <td id="T_6879f_row5_col0" class="data row5 col0" >1.52</td>
#       <td id="T_6879f_row5_col1" class="data row5 col1" >8.6</td>
#       <td id="T_6879f_row5_col2" class="data row5 col2" >9.43</td>
#       <td id="T_6879f_row5_col3" class="data row5 col3" >53.2</td>
#     </tr>
#     <tr>
#       <th id="T_6879f_level0_row6" class="row_heading level0 row6" >Jul</th>
#       <td id="T_6879f_row6_col0" class="data row6 col0" >0.06</td>
#       <td id="T_6879f_row6_col1" class="data row6 col1" >0.6</td>
#       <td id="T_6879f_row6_col2" class="data row6 col2" >7.10</td>
#       <td id="T_6879f_row6_col3" class="data row6 col3" >74.0</td>
#     </tr>
#     <tr>
#       <th id="T_6879f_level0_row7" class="row_heading level0 row7" >Aug</th>
#       <td id="T_6879f_row7_col0" class="data row7 col0" >0.71</td>
#       <td id="T_6879f_row7_col1" class="data row7 col1" >10.9</td>
#       <td id="T_6879f_row7_col2" class="data row7 col2" >4.53</td>
#       <td id="T_6879f_row7_col3" class="data row7 col3" >69.4</td>
#     </tr>
#     <tr>
#       <th id="T_6879f_level0_row8" class="row_heading level0 row8" >Sep</th>
#       <td id="T_6879f_row8_col0" class="data row8 col0" >0.03</td>
#       <td id="T_6879f_row8_col1" class="data row8 col1" >0.5</td>
#       <td id="T_6879f_row8_col2" class="data row8 col2" >4.05</td>
#       <td id="T_6879f_row8_col3" class="data row8 col3" >64.0</td>
#     </tr>
#     <tr>
#       <th id="T_6879f_level0_row9" class="row_heading level0 row9" >Oct</th>
#       <td id="T_6879f_row9_col0" class="data row9 col0" >-0.15</td>
#       <td id="T_6879f_row9_col1" class="data row9 col1" >-1.2</td>
#       <td id="T_6879f_row9_col2" class="data row9 col2" >8.20</td>
#       <td id="T_6879f_row9_col3" class="data row9 col3" >62.7</td>
#     </tr>
#     <tr>
#       <th id="T_6879f_level0_row10" class="row_heading level0 row10" >Nov</th>
#       <td id="T_6879f_row10_col0" class="data row10 col0" >0.31</td>
#       <td id="T_6879f_row10_col1" class="data row10 col1" >1.9</td>
#       <td id="T_6879f_row10_col2" class="data row10 col2" >8.74</td>
#       <td id="T_6879f_row10_col3" class="data row10 col3" >54.0</td>
#     </tr>
#     <tr>
#       <th id="T_6879f_level0_row11" class="row_heading level0 row11" >Dec</th>
#       <td id="T_6879f_row11_col0" class="data row11 col0" >-0.12</td>
#       <td id="T_6879f_row11_col1" class="data row11 col1" >-0.8</td>
#       <td id="T_6879f_row11_col2" class="data row11 col2" >8.61</td>
#       <td id="T_6879f_row11_col3" class="data row11 col3" >53.0</td>
#     </tr>
#   </tbody>
# </table>
# ==================================================== R =================================================
# <style type="text/css">
# #T_da867_row6_col0, #T_da867_row10_col0 {
#   font-weight: bold;
# }
# </style>
# <table id="T_da867">
#   <thead>
#     <tr>
#       <th class="blank level0" >&nbsp;</th>
#       <th id="T_da867_level0_col0" class="col_heading level0 col0" >slope (%/decade)</th>
#       <th id="T_da867_level0_col1" class="col_heading level0 col1" >std (%)</th>
#     </tr>
#   </thead>
#   <tbody>
#     <tr>
#       <th id="T_da867_level0_row0" class="row_heading level0 row0" >Jan</th>
#       <td id="T_da867_row0_col0" class="data row0 col0" >0.06</td>
#       <td id="T_da867_row0_col1" class="data row0 col1" >0.89</td>
#     </tr>
#     <tr>
#       <th id="T_da867_level0_row1" class="row_heading level0 row1" >Feb</th>
#       <td id="T_da867_row1_col0" class="data row1 col0" >0.04</td>
#       <td id="T_da867_row1_col1" class="data row1 col1" >2.00</td>
#     </tr>
#     <tr>
#       <th id="T_da867_level0_row2" class="row_heading level0 row2" >Mar</th>
#       <td id="T_da867_row2_col0" class="data row2 col0" >0.25</td>
#       <td id="T_da867_row2_col1" class="data row2 col1" >3.28</td>
#     </tr>
#     <tr>
#       <th id="T_da867_level0_row3" class="row_heading level0 row3" >Apr</th>
#       <td id="T_da867_row3_col0" class="data row3 col0" >-0.48</td>
#       <td id="T_da867_row3_col1" class="data row3 col1" >6.75</td>
#     </tr>
#     <tr>
#       <th id="T_da867_level0_row4" class="row_heading level0 row4" >May</th>
#       <td id="T_da867_row4_col0" class="data row4 col0" >0.48</td>
#       <td id="T_da867_row4_col1" class="data row4 col1" >8.55</td>
#     </tr>
#     <tr>
#       <th id="T_da867_level0_row5" class="row_heading level0 row5" >Jun</th>
#       <td id="T_da867_row5_col0" class="data row5 col0" >1.37</td>
#       <td id="T_da867_row5_col1" class="data row5 col1" >13.17</td>
#     </tr>
#     <tr>
#       <th id="T_da867_level0_row6" class="row_heading level0 row6" >Jul</th>
#       <td id="T_da867_row6_col0" class="data row6 col0" >8.92</td>
#       <td id="T_da867_row6_col1" class="data row6 col1" >54.06</td>
#     </tr>
#     <tr>
#       <th id="T_da867_level0_row7" class="row_heading level0 row7" >Aug</th>
#       <td id="T_da867_row7_col0" class="data row7 col0" >3.08</td>
#       <td id="T_da867_row7_col1" class="data row7 col1" >70.30</td>
#     </tr>
#     <tr>
#       <th id="T_da867_level0_row8" class="row_heading level0 row8" >Sep</th>
#       <td id="T_da867_row8_col0" class="data row8 col0" >2.04</td>
#       <td id="T_da867_row8_col1" class="data row8 col1" >16.86</td>
#     </tr>
#     <tr>
#       <th id="T_da867_level0_row9" class="row_heading level0 row9" >Oct</th>
#       <td id="T_da867_row9_col0" class="data row9 col0" >0.26</td>
#       <td id="T_da867_row9_col1" class="data row9 col1" >4.71</td>
#     </tr>
#     <tr>
#       <th id="T_da867_level0_row10" class="row_heading level0 row10" >Nov</th>
#       <td id="T_da867_row10_col0" class="data row10 col0" >0.57</td>
#       <td id="T_da867_row10_col1" class="data row10 col1" >3.51</td>
#     </tr>
#     <tr>
#       <th id="T_da867_level0_row11" class="row_heading level0 row11" >Dec</th>
#       <td id="T_da867_row11_col0" class="data row11 col0" >-0.16</td>
#       <td id="T_da867_row11_col1" class="data row11 col1" >1.93</td>
#     </tr>
#   </tbody>
# </table>

# %% [markdown]
# # Monthly evolution of freezing level height (FLH)

# %%
FLH_monthly_timeseries = {}

FLH_monthly_trends = {}
FLH_monthly_trends_stats = {}

FLH_monthly_stats = {}

for i in np.arange(1,13):

    # Selection du i-ème mois
    FLH_monthly = FLH[FLH.index.month == i] 
    FLH_monthly = FLH_monthly.groupby(FLH_monthly.index.year)['FLH'].mean().reset_index()
    FLH_monthly.columns = ['year', 'FLH']
    
    #trend
    FLH_monthly = FLH_monthly[['year', 'FLH']].dropna()
    slope_month_FLH, intercept_month_FLH, r_value_month_FLH, p_value_month_FLH, std_err_month_FLH = stats.linregress(FLH_monthly['year'].values, FLH_monthly['FLH'].values)
    trend_month_FLH = intercept_month_FLH + slope_month_FLH * FLH_monthly['year'].values
    
    #statistics
    mean_month_FLH = np.mean(FLH_monthly['FLH'].values)
    std_month_FLH = np.std(FLH_monthly['FLH'].values)
    min_month_FLH = np.min(FLH_monthly['FLH'].values)
    max_month_FLH = np.max(FLH_monthly['FLH'].values)

    FLH_monthly_timeseries[i] = FLH_monthly

    FLH_monthly_trends[i] = trend_month_FLH
    FLH_monthly_trends_stats[i] = [slope_month_FLH, intercept_month_FLH, r_value_month_FLH, p_value_month_FLH, std_err_month_FLH]
    
    FLH_monthly_stats[i] = [mean_month_FLH, std_month_FLH, min_month_FLH, max_month_FLH]

# %%
#====================== statistics tab ==============================================================================

table = pd.DataFrame(index=months, columns=['slope (m/decade)', 'slope (%/decade)', 'std (m)', 'std (%)'])
pvals = pd.DataFrame(index=months, columns=['slope (m/decade)', 'slope (%/decade)', 'std (m)', 'std (%)'])

for i in np.arange(1,13):

    FLH_slope = FLH_monthly_trends_stats[i][0] * 10
    FLH_pval  = FLH_monthly_trends_stats[i][3]
    FLH_slope_percentage = FLH_slope /  FLH_monthly_stats[i][0] * 100
    FLH_std = FLH_monthly_stats[i][1]
    FLH_std_percentage = FLH_std /  FLH_monthly_stats[i][0] * 100

    table.loc[months[i-1], 'slope (m/decade)'] = FLH_slope
    table.loc[months[i-1], 'slope (%/decade)'] = FLH_slope_percentage
    table.loc[months[i-1], 'std (m)'] = FLH_std
    table.loc[months[i-1], 'std (%)'] = FLH_std_percentage

    
    pvals.loc[months[i-1], 'slope (m/decade)'] = FLH_pval
    pvals.loc[months[i-1], 'slope (%/decade)'] = FLH_pval

def bold_sig(val, p):
    if p < 0.05:
        return 'font-weight: bold'
    return ''

formats = {
    'slope (m/decade)': "{:.0f}",
    'slope (%/decade)': "{:.1f}",
    'std (m)': "{:.0f}",      
    'std (%)': "{:.1f}"
}

styled_table = table.style.apply(
    lambda x: [bold_sig(v, pvals.loc[x.name, col]) for col, v in x.items()],
    axis=1
).format(formats, na_rep='-')

display(styled_table)

#======================== plot ============================================================================================

fig, axes = plt.subplots(6, 2, figsize=(16,20))
axes = axes.flatten()

for i, ax in enumerate(axes):
    
    ax.plot(FLH_monthly_timeseries[i+1]['year'].values, FLH_monthly_timeseries[i+1]['FLH'].values, color='orange', label='FLH', linewidth=2)
    ax.plot(FLH_monthly_timeseries[i+1]['year'].values, FLH_monthly_trends[i+1], color='orange', linewidth=1, linestyle='--')

    ax.set_title(months[i], fontsize=16, weight="bold")
    
    if i in [0, 2, 4, 6, 8, 10]:  # colonne gauche
        ax.set_ylabel('FLH (m)', fontsize=12)
        
    if i in [10, 11]:  # ligne du bas
        ax.set_xlabel('year', fontsize=12)
    else:
        ax.tick_params(labelbottom=False)
    
    ax.grid(True, linestyle='--', alpha=0.5, zorder=0)
    
# --- legend
handles, labels = axes[0].get_legend_handles_labels()
fig.legend(
    handles,
    labels,
    loc='lower center',
    bbox_to_anchor=(0.5, -0.04),
    ncol=3,
    fontsize=16,
    frameon=True
)
    
plt.tight_layout()
plt.show()
# Out:
# <style type="text/css">
# #T_4ecfe_row2_col0, #T_4ecfe_row2_col1, #T_4ecfe_row4_col0, #T_4ecfe_row4_col1, #T_4ecfe_row6_col0, #T_4ecfe_row6_col1, #T_4ecfe_row8_col0, #T_4ecfe_row8_col1, #T_4ecfe_row9_col0, #T_4ecfe_row9_col1 {
#   font-weight: bold;
# }
# </style>
# <table id="T_4ecfe">
#   <thead>
#     <tr>
#       <th class="blank level0" >&nbsp;</th>
#       <th id="T_4ecfe_level0_col0" class="col_heading level0 col0" >slope (m/decade)</th>
#       <th id="T_4ecfe_level0_col1" class="col_heading level0 col1" >slope (%/decade)</th>
#       <th id="T_4ecfe_level0_col2" class="col_heading level0 col2" >std (m)</th>
#       <th id="T_4ecfe_level0_col3" class="col_heading level0 col3" >std (%)</th>
#     </tr>
#   </thead>
#   <tbody>
#     <tr>
#       <th id="T_4ecfe_level0_row0" class="row_heading level0 row0" >Jan</th>
#       <td id="T_4ecfe_row0_col0" class="data row0 col0" >31</td>
#       <td id="T_4ecfe_row0_col1" class="data row0 col1" >2.5</td>
#       <td id="T_4ecfe_row0_col2" class="data row0 col2" >251</td>
#       <td id="T_4ecfe_row0_col3" class="data row0 col3" >19.9</td>
#     </tr>
#     <tr>
#       <th id="T_4ecfe_level0_row1" class="row_heading level0 row1" >Feb</th>
#       <td id="T_4ecfe_row1_col0" class="data row1 col0" >40</td>
#       <td id="T_4ecfe_row1_col1" class="data row1 col1" >2.3</td>
#       <td id="T_4ecfe_row1_col2" class="data row1 col2" >402</td>
#       <td id="T_4ecfe_row1_col3" class="data row1 col3" >23.3</td>
#     </tr>
#     <tr>
#       <th id="T_4ecfe_level0_row2" class="row_heading level0 row2" >Mar</th>
#       <td id="T_4ecfe_row2_col0" class="data row2 col0" >47</td>
#       <td id="T_4ecfe_row2_col1" class="data row2 col1" >1.8</td>
#       <td id="T_4ecfe_row2_col2" class="data row2 col2" >267</td>
#       <td id="T_4ecfe_row2_col3" class="data row2 col3" >10.4</td>
#     </tr>
#     <tr>
#       <th id="T_4ecfe_level0_row3" class="row_heading level0 row3" >Apr</th>
#       <td id="T_4ecfe_row3_col0" class="data row3 col0" >16</td>
#       <td id="T_4ecfe_row3_col1" class="data row3 col1" >0.5</td>
#       <td id="T_4ecfe_row3_col2" class="data row3 col2" >183</td>
#       <td id="T_4ecfe_row3_col3" class="data row3 col3" >5.5</td>
#     </tr>
#     <tr>
#       <th id="T_4ecfe_level0_row4" class="row_heading level0 row4" >May</th>
#       <td id="T_4ecfe_row4_col0" class="data row4 col0" >34</td>
#       <td id="T_4ecfe_row4_col1" class="data row4 col1" >0.8</td>
#       <td id="T_4ecfe_row4_col2" class="data row4 col2" >236</td>
#       <td id="T_4ecfe_row4_col3" class="data row4 col3" >5.9</td>
#     </tr>
#     <tr>
#       <th id="T_4ecfe_level0_row5" class="row_heading level0 row5" >Jun</th>
#       <td id="T_4ecfe_row5_col0" class="data row5 col0" >8</td>
#       <td id="T_4ecfe_row5_col1" class="data row5 col1" >0.2</td>
#       <td id="T_4ecfe_row5_col2" class="data row5 col2" >120</td>
#       <td id="T_4ecfe_row5_col3" class="data row5 col3" >2.6</td>
#     </tr>
#     <tr>
#       <th id="T_4ecfe_level0_row6" class="row_heading level0 row6" >Jul</th>
#       <td id="T_4ecfe_row6_col0" class="data row6 col0" >15</td>
#       <td id="T_4ecfe_row6_col1" class="data row6 col1" >0.3</td>
#       <td id="T_4ecfe_row6_col2" class="data row6 col2" >106</td>
#       <td id="T_4ecfe_row6_col3" class="data row6 col3" >2.1</td>
#     </tr>
#     <tr>
#       <th id="T_4ecfe_level0_row7" class="row_heading level0 row7" >Aug</th>
#       <td id="T_4ecfe_row7_col0" class="data row7 col0" >5</td>
#       <td id="T_4ecfe_row7_col1" class="data row7 col1" >0.1</td>
#       <td id="T_4ecfe_row7_col2" class="data row7 col2" >85</td>
#       <td id="T_4ecfe_row7_col3" class="data row7 col3" >1.7</td>
#     </tr>
#     <tr>
#       <th id="T_4ecfe_level0_row8" class="row_heading level0 row8" >Sep</th>
#       <td id="T_4ecfe_row8_col0" class="data row8 col0" >27</td>
#       <td id="T_4ecfe_row8_col1" class="data row8 col1" >0.6</td>
#       <td id="T_4ecfe_row8_col2" class="data row8 col2" >142</td>
#       <td id="T_4ecfe_row8_col3" class="data row8 col3" >3.2</td>
#     </tr>
#     <tr>
#       <th id="T_4ecfe_level0_row9" class="row_heading level0 row9" >Oct</th>
#       <td id="T_4ecfe_row9_col0" class="data row9 col0" >22</td>
#       <td id="T_4ecfe_row9_col1" class="data row9 col1" >0.7</td>
#       <td id="T_4ecfe_row9_col2" class="data row9 col2" >169</td>
#       <td id="T_4ecfe_row9_col3" class="data row9 col3" >5.0</td>
#     </tr>
#     <tr>
#       <th id="T_4ecfe_level0_row10" class="row_heading level0 row10" >Nov</th>
#       <td id="T_4ecfe_row10_col0" class="data row10 col0" >34</td>
#       <td id="T_4ecfe_row10_col1" class="data row10 col1" >1.4</td>
#       <td id="T_4ecfe_row10_col2" class="data row10 col2" >297</td>
#       <td id="T_4ecfe_row10_col3" class="data row10 col3" >11.9</td>
#     </tr>
#     <tr>
#       <th id="T_4ecfe_level0_row11" class="row_heading level0 row11" >Dec</th>
#       <td id="T_4ecfe_row11_col0" class="data row11 col0" >16</td>
#       <td id="T_4ecfe_row11_col1" class="data row11 col1" >1.0</td>
#       <td id="T_4ecfe_row11_col2" class="data row11 col2" >410</td>
#       <td id="T_4ecfe_row11_col3" class="data row11 col3" >26.9</td>
#     </tr>
#   </tbody>
# </table>
