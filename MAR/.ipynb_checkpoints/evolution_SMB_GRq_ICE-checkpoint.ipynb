# %%
import sys
sys.path.insert(1, '/home/bricej/MyPythonLibrary/StageM2_IVT/library/')
import domain
from domain import *
from climbas import *
import numpy as np
import xarray as xr
import pandas as pd
from netCDF4 import Dataset
from scipy import stats
import scipy.stats as stats
import matplotlib.pyplot as plt
import matplotlib.cm as cm
import matplotlib.colors as mcolors

# %% [markdown]
# # Period & Domain

# %%
iyear=1960
fyear=2024
nx=10;ny=10
dom='GRq'
dom_NST = 'GRc'
year_NST = '2000'

# %% [markdown]
# # SMB Data

# %%
SMB = xr.open_mfdataset(f'/bettik/PROJECTS/pr-regional-climate/santolam/MARout_post/{dom}/spin2/work/monthly/SMB_monsum_MARv3.14_ER5_spin2_{dom}_*.nc',
                       combine="by_coords")['SMB']

#Domain & period def
SMB = SMB.rename({'TIME': 'time'})
SMB = SMB[:,:,ny:-ny,nx:-nx].sel(time=slice(str(iyear),str(fyear)))

# .isel(SECTOR=0) = ICE domain / .isel(SECTOR=1) = partout ou presque je sais plus
SMB = SMB.isel(SECTOR=0)

# %% [markdown]
# # ICE mask

# %%
# ICE data
ds_grM= xr.open_dataset(f'/home/santolam/NST.{year_NST}.01.01.00.{dom_NST}.nc')
dsICE = ds_grM.ICE[ny:-ny,nx:-nx]

#ICE mask
ICE_mask = dsICE > 0
ICE_mask = ICE_mask.rename({'x': 'X', 'y': 'Y'})
ICE_mask.plot()

# %%
ICE_mask = ICE_mask.assign_coords({
    "X": SMB.X,
    "Y": SMB.Y
})
SMB = SMB.where(ICE_mask)

# %% [markdown]
# # Annual Mean

# %%
SMB_mean = SMB.groupby('time.year').mean('time', skipna=True)
SMB_mean = SMB_mean.mean(dim=['Y','X'], skipna=True)

# %% [markdown]
# # Trends

# %%
mask = ~np.isnan(SMB_mean.values)
slope_SMB, intercept_SMB, r_value_SMB, p_value_SMB, std_err_SMB = stats.linregress(SMB_mean['year'].values[mask], SMB_mean.values[mask])
trend_SMB = intercept_SMB + slope_SMB * SMB_mean['year'].values

# %% [markdown]
# # Statistics

# %%
mean_SMB = np.nanmean(SMB_mean.values)
std_SMB = np.nanstd(SMB_mean.values)
min_SMB = np.nanmin(SMB_mean.values)
max_SMB = np.nanmax(SMB_mean.values)

# %%
print(f'SMB : {slope_SMB * 10:.2f} mm w.e. / month / decade (p={p_value_SMB:.3f}) ({(slope_SMB*10)/np.abs(mean_SMB)*100:.1f} %/decade) (std={np.abs(std_SMB/mean_SMB*100):.1f} %)\n')

fig, ax = plt.subplots(figsize=(8,5))

ax.plot(SMB_mean['year'].values, SMB_mean.values, color='blueviolet', label='SMB', linewidth=2)
ax.plot(SMB_mean['year'].values, trend_SMB, color='blueviolet', linewidth=1, linestyle='--')

ax.grid(True, linestyle='--', alpha=0.5, zorder=0)
ax.set_xlabel('year')
ax.set_ylabel('SMB (mm w.e./month)')

# --- legend
ax.legend(fontsize=9)

plt.tight_layout()
plt.show()
# Out:
# SMB : -5.93 mm w.e. / month / decade (p=0.001) (-10.1 %/decade) (std=45.8 %)

# %% [markdown]
# # Monthly timeseries

# %%
SMB_monthly_timeseries = {}

for i in np.arange(1,13):
    
    # Selection of a single month through the all period
    SMB_month = SMB.sel(time=SMB.time.dt.month == i)
    
    # Monthly mean for month i
    SMB_monthly = SMB_month.groupby('time.year').mean('time', skipna=True)
    SMB_monthly = SMB_monthly.mean(dim=['Y','X'], skipna=True)
    
    SMB_monthly_timeseries[i] = SMB_monthly

# %% [markdown]
# # Monthly trends

# %%
SMB_monthly_trends = {}

SMB_monthly_trends_stats = {}

for i in np.arange(1,13):

    SMB_mask = ~np.isnan(SMB_monthly_timeseries[i].values)
    slope_month_SMB, intercept_month_SMB, r_value_month_SMB, p_value_month_SMB, std_err_month_SMB = stats.linregress(SMB_monthly_timeseries[i]['year'].values[mask], SMB_monthly_timeseries[i].values[mask])
    trend_month_SMB = intercept_month_SMB + slope_month_SMB * SMB_monthly_timeseries[i]['year'].values

    SMB_monthly_trends_stats[i] = [slope_month_SMB, intercept_month_SMB, r_value_month_SMB, p_value_month_SMB, std_err_month_SMB]
    
    SMB_monthly_trends[i] = trend_month_SMB

# %% [markdown]
# # Monthly statistics

# %%
SMB_monthly_stats = {}

for i in np.arange(1,13):

    mean_month_SMB = np.nanmean(SMB_monthly_timeseries[i].values)
    std_month_SMB = np.nanstd(SMB_monthly_timeseries[i].values)
    min_month_SMB = np.nanmin(SMB_monthly_timeseries[i].values)
    max_month_SMB = np.nanmax(SMB_monthly_timeseries[i].values)

    SMB_monthly_stats[i] = [mean_month_SMB, std_month_SMB, min_month_SMB, max_month_SMB]

# %%
months = ['Jan','Feb','Mar','Apr','May','Jun','Jul','Aug','Sep','Oct','Nov','Dec']

#====================== statistics tab ==============================================================================

def bold_sig(val, p):
    if p < 0.05:
        return 'font-weight: bold'
    return ''

#========= RF ================
print('==================================================== SMB =================================================')

table = pd.DataFrame(index=months, columns=['slope (mm/month/decade)', 'slope (%/decade)', 'std (mm/month)', 'std (%)'])
pvals = pd.DataFrame(index=months, columns=['slope (mm/month/decade)', 'slope (%/decade)', 'std (mm/month)', 'std (%)'])

for i in np.arange(1,13):

    SMB_slope = SMB_monthly_trends_stats[i][0] * 10
    SMB_pval  = SMB_monthly_trends_stats[i][3]
    SMB_slope_percentage = SMB_slope /  SMB_monthly_stats[i][0] * 100
    SMB_std = SMB_monthly_stats[i][1]
    SMB_std_percentage = SMB_std /  SMB_monthly_stats[i][0] * 100

    table.loc[months[i-1], 'slope (mm/month/decade)'] = SMB_slope
    table.loc[months[i-1], 'slope (%/decade)'] = SMB_slope_percentage
    table.loc[months[i-1], 'std (mm/month)'] = SMB_std
    table.loc[months[i-1], 'std (%)'] = SMB_std_percentage

    
    pvals.loc[months[i-1], 'slope (mm/month/decade)'] = SMB_pval
    pvals.loc[months[i-1], 'slope (%/decade)'] = SMB_pval

formats = {
    'slope (mm/month/decade)': "{:.2f}",
    'slope (%/decade)': "{:.1f}",
    'std (mm/month)': "{:.2f}",      
    'std (%)': "{:.1f}"
}

styled_table = table.style.apply(
    lambda x: [bold_sig(v, pvals.loc[x.name, col]) for col, v in x.items()],
    axis=1
).format(formats, na_rep='-')

display(styled_table)

#======================== plot ============================================================================================

fig, axes = plt.subplots(6, 2, figsize=(16,20))
axes = axes.flatten()

for i, ax in enumerate(axes):
    
    ax.plot(SMB_monthly_timeseries[i+1]['year'].values, SMB_monthly_timeseries[i+1].values, color='blueviolet', label='SMB', linewidth=2)
    ax.plot(SMB_monthly_timeseries[i+1]['year'].values, SMB_monthly_trends[i+1], color='blueviolet', linewidth=1, linestyle='--')

    ax.set_title(months[i], fontsize=16, weight="bold")
    
    if i in [0, 2, 4, 6, 8, 10]:  # colonne gauche
        ax.set_ylabel('SMB (mm w.e./month)', fontsize=12)
        
    if i in [10, 11]:  # ligne du bas
        ax.set_xlabel('year', fontsize=12)
    else:
        ax.tick_params(labelbottom=False)
    
    ax.grid(True, linestyle='--', alpha=0.5, zorder=0)
    
# --- legend
handles, labels = axes[0].get_legend_handles_labels()
fig.legend(
    handles,
    labels,
    loc='lower center',
    bbox_to_anchor=(0.5, -0.04),
    ncol=3,
    fontsize=16,
    frameon=True
)
    
plt.tight_layout()
plt.show()
# Out:
# ==================================================== SMB =================================================
# <style type="text/css">
# #T_885b1_row5_col0, #T_885b1_row5_col1, #T_885b1_row7_col0, #T_885b1_row7_col1, #T_885b1_row8_col0, #T_885b1_row8_col1, #T_885b1_row10_col0, #T_885b1_row10_col1 {
#   font-weight: bold;
# }
# </style>
# <table id="T_885b1">
#   <thead>
#     <tr>
#       <th class="blank level0" >&nbsp;</th>
#       <th id="T_885b1_level0_col0" class="col_heading level0 col0" >slope (mm/month/decade)</th>
#       <th id="T_885b1_level0_col1" class="col_heading level0 col1" >slope (%/decade)</th>
#       <th id="T_885b1_level0_col2" class="col_heading level0 col2" >std (mm/month)</th>
#       <th id="T_885b1_level0_col3" class="col_heading level0 col3" >std (%)</th>
#     </tr>
#   </thead>
#   <tbody>
#     <tr>
#       <th id="T_885b1_level0_row0" class="row_heading level0 row0" >Jan</th>
#       <td id="T_885b1_row0_col0" class="data row0 col0" >-1.46</td>
#       <td id="T_885b1_row0_col1" class="data row0 col1" >-5.7</td>
#       <td id="T_885b1_row0_col2" class="data row0 col2" >26.43</td>
#       <td id="T_885b1_row0_col3" class="data row0 col3" >103.9</td>
#     </tr>
#     <tr>
#       <th id="T_885b1_level0_row1" class="row_heading level0 row1" >Feb</th>
#       <td id="T_885b1_row1_col0" class="data row1 col0" >1.91</td>
#       <td id="T_885b1_row1_col1" class="data row1 col1" >5.6</td>
#       <td id="T_885b1_row1_col2" class="data row1 col2" >30.03</td>
#       <td id="T_885b1_row1_col3" class="data row1 col3" >88.5</td>
#     </tr>
#     <tr>
#       <th id="T_885b1_level0_row2" class="row_heading level0 row2" >Mar</th>
#       <td id="T_885b1_row2_col0" class="data row2 col0" >-1.75</td>
#       <td id="T_885b1_row2_col1" class="data row2 col1" >-4.1</td>
#       <td id="T_885b1_row2_col2" class="data row2 col2" >31.41</td>
#       <td id="T_885b1_row2_col3" class="data row2 col3" >74.0</td>
#     </tr>
#     <tr>
#       <th id="T_885b1_level0_row3" class="row_heading level0 row3" >Apr</th>
#       <td id="T_885b1_row3_col0" class="data row3 col0" >-0.82</td>
#       <td id="T_885b1_row3_col1" class="data row3 col1" >-2.2</td>
#       <td id="T_885b1_row3_col2" class="data row3 col2" >51.07</td>
#       <td id="T_885b1_row3_col3" class="data row3 col3" >136.3</td>
#     </tr>
#     <tr>
#       <th id="T_885b1_level0_row4" class="row_heading level0 row4" >May</th>
#       <td id="T_885b1_row4_col0" class="data row4 col0" >6.34</td>
#       <td id="T_885b1_row4_col1" class="data row4 col1" >-23.4</td>
#       <td id="T_885b1_row4_col2" class="data row4 col2" >65.40</td>
#       <td id="T_885b1_row4_col3" class="data row4 col3" >-241.8</td>
#     </tr>
#     <tr>
#       <th id="T_885b1_level0_row5" class="row_heading level0 row5" >Jun</th>
#       <td id="T_885b1_row5_col0" class="data row5 col0" >-17.07</td>
#       <td id="T_885b1_row5_col1" class="data row5 col1" >8.2</td>
#       <td id="T_885b1_row5_col2" class="data row5 col2" >112.16</td>
#       <td id="T_885b1_row5_col3" class="data row5 col3" >-53.6</td>
#     </tr>
#     <tr>
#       <th id="T_885b1_level0_row6" class="row_heading level0 row6" >Jul</th>
#       <td id="T_885b1_row6_col0" class="data row6 col0" >-11.88</td>
#       <td id="T_885b1_row6_col1" class="data row6 col1" >4.3</td>
#       <td id="T_885b1_row6_col2" class="data row6 col2" >104.51</td>
#       <td id="T_885b1_row6_col3" class="data row6 col3" >-37.5</td>
#     </tr>
#     <tr>
#       <th id="T_885b1_level0_row7" class="row_heading level0 row7" >Aug</th>
#       <td id="T_885b1_row7_col0" class="data row7 col0" >-22.23</td>
#       <td id="T_885b1_row7_col1" class="data row7 col1" >10.0</td>
#       <td id="T_885b1_row7_col2" class="data row7 col2" >102.05</td>
#       <td id="T_885b1_row7_col3" class="data row7 col3" >-46.0</td>
#     </tr>
#     <tr>
#       <th id="T_885b1_level0_row8" class="row_heading level0 row8" >Sep</th>
#       <td id="T_885b1_row8_col0" class="data row8 col0" >-13.23</td>
#       <td id="T_885b1_row8_col1" class="data row8 col1" >16.3</td>
#       <td id="T_885b1_row8_col2" class="data row8 col2" >81.20</td>
#       <td id="T_885b1_row8_col3" class="data row8 col3" >-100.0</td>
#     </tr>
#     <tr>
#       <th id="T_885b1_level0_row9" class="row_heading level0 row9" >Oct</th>
#       <td id="T_885b1_row9_col0" class="data row9 col0" >-7.57</td>
#       <td id="T_885b1_row9_col1" class="data row9 col1" >25.1</td>
#       <td id="T_885b1_row9_col2" class="data row9 col2" >63.85</td>
#       <td id="T_885b1_row9_col3" class="data row9 col3" >-211.6</td>
#     </tr>
#     <tr>
#       <th id="T_885b1_level0_row10" class="row_heading level0 row10" >Nov</th>
#       <td id="T_885b1_row10_col0" class="data row10 col0" >-2.74</td>
#       <td id="T_885b1_row10_col1" class="data row10 col1" >680.0</td>
#       <td id="T_885b1_row10_col2" class="data row10 col2" >20.23</td>
#       <td id="T_885b1_row10_col3" class="data row10 col3" >-5028.3</td>
#     </tr>
#     <tr>
#       <th id="T_885b1_level0_row11" class="row_heading level0 row11" >Dec</th>
#       <td id="T_885b1_row11_col0" class="data row11 col0" >-0.63</td>
#       <td id="T_885b1_row11_col1" class="data row11 col1" >-8.6</td>
#       <td id="T_885b1_row11_col2" class="data row11 col2" >23.60</td>
#       <td id="T_885b1_row11_col3" class="data row11 col3" >324.6</td>
#     </tr>
#   </tbody>
# </table>
