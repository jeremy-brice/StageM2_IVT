# %%
import sys
sys.path.insert(1, '/home/bricej/MyPythonLibrary/StageM2_IVT/library/')
import numpy.ma as ma
from domain import *
import xarray as xr
from netCDF4 import Dataset
import cartopy.crs as ccrs
import cartopy.feature as cfeature
import matplotlib.pyplot as plt
import matplotlib.colors as mcolors
import matplotlib.patches as mpatches
from matplotlib.patches import Rectangle
import calendar

# %%
dsHMA=xr.open_dataset('/home/santolam/NST.2000.09.01.00.GRh.nc')
dsSH_hma=dsHMA['SH']#[nx:-nx,ny:-ny]
LONS_hma,LATS_hma=dsHMA.LON,dsHMA.LAT

# %%
dsSH_hma
# Out:
# <xarray.DataArray 'SH' (y: 320, x: 640)> Size: 819kB
# [204800 values with dtype=float32]
# Coordinates:
#   * x        (x) float32 3kB -2.233e+03 -2.226e+03 ... 2.233e+03 2.24e+03
#   * y        (y) float32 1kB -1.113e+03 -1.106e+03 ... 1.113e+03 1.12e+03
# Attributes:
#     units:          m
#     long_name:      Surface height
#     standard_name:  Surface_height
#     actual_range:   [   0.     6785.2705]
#     valid_range:    [-1.e+20  1.e+20]
