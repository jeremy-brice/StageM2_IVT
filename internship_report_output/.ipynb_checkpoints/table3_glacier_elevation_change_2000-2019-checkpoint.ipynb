# %%
import pandas as pd

# %% [markdown]
# # Glacier evolution (2000-2019) data loading
#
# The values were computed by doing a mean of the values obtained in the Hugonnet et al. (2021) dataset (/bettik/PROJECTS/pr-regional-climate/bricej/dh_HIMAP_rates.csv) for the subregions in the regions defined in green in Fig2 & for the longest period available 2000-2019. For more details, go to : /StageM2_IVT/papier/dh-dt_HIMAPgrouped_2000-2019.ipynb

# %%
ds = pd.read_csv('/bettik/PROJECTS/pr-regional-climate/bricej/paper/dhdt_2000-2019_HIMAPgrouped_regions.csv')
ds
# Out:
#               region      dhdt  err_dhdt
# 0          Tien Shan -0.458750  0.029676
# 1         Pamir Alay -0.122000  0.038000
# 2              Pamir -0.138000  0.033000
# 3         Hindu Kush -0.193000  0.035000
# 4          Karakoram -0.073000  0.030000
# 5             Kunlun  0.080000  0.026768
# 6       Spiti Lahaul -0.383000  0.043000
# 7   Central Himalaya -0.477000  0.040000
# 8             Bhutan -0.538000  0.051000
# 9     Nyainqentangla -0.704000  0.062000
# 10          Inner TP -0.378875  0.018911
