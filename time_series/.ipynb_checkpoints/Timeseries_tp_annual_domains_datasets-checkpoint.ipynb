# %%
import sys
sys.path.insert(1, '/home/bricej/MyPythonLibrary/StageM2_IVT/library/')
import domain
from domain import *
from climbas import *
import numpy as np
import xarray as xr
import pandas as pd
from netCDF4 import Dataset
from scipy import stats
import scipy.stats as stats
import matplotlib.pyplot as plt

# %% [markdown]
# # Common Period

# %%
iyear = 1981
fyear = 2015
models = ['APHRO','CHIRPS','CRU','ERA5','GPCP','HARv2']
domains = ['HMA','HK','SL','TP','CH','SEH']

# %% [markdown]
# # TP timeseries DATASETS & DOMAINS

# %% [markdown]
# ## Annual

# %%
tp_datasets = {}
stats_datasets = {}

path = '/bettik/PROJECTS/pr-regional-climate/bricej/results/timeseries/'

for model in models:
    tp_datasets[model] = {}
    stats_datasets[model] = {}
    for domain in domains:
        tp_datasets[model][domain] = pd.read_csv(path + f'timeseries_tp_annual_{domain}_1981-2015_{model}.csv')
        stats_datasets[model][domain] = pd.read_csv(path + f'stats_tp_annual_{domain}_1981-2015_{model}.csv')

# %%
resolutions = {'APHRO': '0.25°x0.25°',
               'GPCP': '1.0°x1.0°',
               'CRU': '0.5°x0.5°',
               'CHIRPS': '0.05°x0.05°',
               'HARv2': '10kmx10km',
               'ERA5': '0.25°x0.25°'}

#============== tableau des p-values ==========================

table = pd.DataFrame(index=models, columns=domains)
pvals = pd.DataFrame(index=models, columns=domains)

for model in models:
    for dom in domains:

        df = stats_datasets[model][dom]

        slope = df.loc[df['stat']=='slope','value'].values[0] * 10
        pval  = df.loc[df['stat']=='p_value','value'].values[0]

        table.loc[model, dom] = slope
        pvals.loc[model, dom] = pval

def bold_sig(val, p):
    if p < 0.05:
        return 'font-weight: bold'
    return ''

styled_table = table.style.apply(
    lambda x: [bold_sig(v, pvals.loc[x.name, col]) for col, v in x.items()],
    axis=1
).format("{:.2f}")

display(styled_table)

# ====================== plot time series ========================

fig, axes = plt.subplots(3, 2, figsize=(16,14))
axes = axes.flatten()

for i, dom in enumerate(domains):

    ax = axes[i]

    for model in models:
        da = tp_datasets[model][dom]
        ax.plot(da['year'], da['tp'], linestyle='-', label=f'{model} ({resolutions[model]})', linewidth=1.5)

    ax.set_title(dom, fontsize=16, weight="bold")
    
    if i in [0, 2, 4]:  # colonne gauche
        ax.set_ylabel('tp (mm month⁻¹)', fontsize=12)
    if i in [4, 5]:  # ligne du bas
        ax.tick_params(labelbottom=True)
    if i in [0,1,2,3]:
        ax.tick_params(labelbottom=False)
    
    ax.grid(True, linestyle='--', alpha=0.5)

handles, labels = axes[0].get_legend_handles_labels()
fig.legend(
    handles,
    labels,
    loc='lower center',
    bbox_to_anchor=(0.5, -0.04),
    ncol=3,
    fontsize=16,
    frameon=True
)
fig.suptitle(f'Annual Time series Precipitation ({iyear}-{fyear})', fontsize=16, weight='bold')

plt.tight_layout(rect=[0,0.05,1,1])
plt.show()
# Out:
# <style type="text/css">
# #T_cdadc_row0_col0, #T_cdadc_row0_col1, #T_cdadc_row0_col3, #T_cdadc_row1_col0, #T_cdadc_row1_col1, #T_cdadc_row1_col3, #T_cdadc_row3_col3, #T_cdadc_row3_col5, #T_cdadc_row4_col3, #T_cdadc_row4_col4, #T_cdadc_row5_col3 {
#   font-weight: bold;
# }
# </style>
# <table id="T_cdadc">
#   <thead>
#     <tr>
#       <th class="blank level0" >&nbsp;</th>
#       <th id="T_cdadc_level0_col0" class="col_heading level0 col0" >HMA</th>
#       <th id="T_cdadc_level0_col1" class="col_heading level0 col1" >HK</th>
#       <th id="T_cdadc_level0_col2" class="col_heading level0 col2" >SL</th>
#       <th id="T_cdadc_level0_col3" class="col_heading level0 col3" >TP</th>
#       <th id="T_cdadc_level0_col4" class="col_heading level0 col4" >CH</th>
#       <th id="T_cdadc_level0_col5" class="col_heading level0 col5" >SEH</th>
#     </tr>
#   </thead>
#   <tbody>
#     <tr>
#       <th id="T_cdadc_level0_row0" class="row_heading level0 row0" >APHRO</th>
# ...

# %% [markdown]
# ## BOX PLOT

# %%
fig, axes = plt.subplots(3, 2, figsize=(16,14))
axes = axes.flatten()

for i, dom in enumerate(domains):
    ax = axes[i]

    data_to_plot = []
    labels_to_plot = []

    for model in models:
        da = tp_datasets[model][dom]['tp']
        data_to_plot.append(da.values)
        labels_to_plot.append(model)

    # créer le boxplot
    bp = ax.boxplot(data_to_plot, tick_labels=labels_to_plot, patch_artist=False)

    # axes et style
    if i in [0, 2, 4]:
        ax.set_ylabel('tp (mm month⁻¹)', fontsize=12)
    if i in [4, 5]:
        ax.tick_params(labelbottom=True)
        ax.tick_params(axis='x', labelsize=20)
    if i in [0,1,2,3]:
        ax.tick_params(labelbottom=False)

    ax.set_title(dom, fontsize=16, weight='bold')
    ax.grid(True, linestyle='--', alpha=0.5, axis='y')
    ax.tick_params(axis='x', rotation=45)

fig.suptitle(f'Annual Precipitation Distribution ({iyear}-{fyear})', fontsize=16, weight='bold')
plt.tight_layout(rect=[0,0.03,1,0.95])
fig.subplots_adjust(top=0.93) 
plt.show()

# %% [markdown]
# # Trend plot

# %%
fig, axes = plt.subplots(3, 2, figsize=(16,14))
axes = axes.flatten()

colors = {'APHRO':'blue', 'GPCP':'orange', 'CRU':'green',
          'CHIRPS':'red', 'HARv2':'purple', 'ERA5':'brown'}

for i, dom in enumerate(domains):
    ax = axes[i]

    x = range(1, len(models)+1)
    slopes = []
    errors = []

    for xi, model in zip(x, models):
        df = stats_datasets[model][dom]
        slope = df.loc[df['stat']=='slope', 'value'].values[0] *10
        std_err = df.loc[df['stat']=='std_err', 'value'].values[0] *10
        p_value = df.loc[df['stat']=='p_value', 'value'].values[0]

        if p_value <= 0.05:
            # plot point + barre d'erreur
            ax.errorbar(xi, slope, yerr=std_err, fmt='o', color=colors[model],
                        ecolor=colors[model], elinewidth=2, capsize=5, markersize=8)
        else:
            ax.errorbar(xi, slope, yerr=std_err, fmt='o', color='black',
                        ecolor='black', elinewidth=2, capsize=5, markersize=8, alpha=0.5)

    # axes et style
    if i in [0, 2, 4]:
        ax.set_ylabel('tp trend (mm/month/decade)', fontsize=12)
    if i in [4, 5]:
        ax.set_xticks(x)
        ax.set_xticklabels(models, rotation=45, fontsize=16)
    if i in [0,1,2,3]:
        ax.tick_params(labelbottom=False)

    ax.set_title(dom, fontsize=16, weight='bold')
    ax.grid(True, linestyle='--', alpha=0.5, axis='y')

fig.suptitle(f'Annual Precipitation Trends ({iyear}-{fyear})', fontsize=16, weight='bold')
plt.tight_layout(rect=[0,0.03,1,0.95])
fig.subplots_adjust(top=0.93)
plt.show()

# %% [markdown]
# # All period for every dataset

# %%
iyear = 1891
fyear = 2025
models = ['APHRO','CHIRPS','CRU','ERA5','GPCP','HARv2']
domains = ['HMA','HK','SL','TP','CH','SEH']

# %%
tp_datasets = {}
stats_datasets = {}

path = '/bettik/PROJECTS/pr-regional-climate/bricej/results/timeseries/'

model=models[0]
tp_datasets[model] = {}
stats_datasets[model] = {}
for domain in domains:
    tp_datasets[model][domain] = pd.read_csv(path + f'timeseries_tp_annual_{domain}_1951-2015_{model}.csv')
    stats_datasets[model][domain] = pd.read_csv(path + f'stats_tp_annual_{domain}_1951-2015_{model}.csv')

model=models[4]
tp_datasets[model] = {}
stats_datasets[model] = {}
for domain in domains:
    tp_datasets[model][domain] = pd.read_csv(path + f'timeseries_tp_annual_{domain}_1891-2019_{model}.csv')
    stats_datasets[model][domain] = pd.read_csv(path + f'stats_tp_annual_{domain}_1891-2019_{model}.csv')

model=models[2]
tp_datasets[model] = {}
stats_datasets[model] = {}
for domain in domains:
    tp_datasets[model][domain] = pd.read_csv(path + f'timeseries_tp_annual_{domain}_1901-2020_{model}.csv')
    stats_datasets[model][domain] = pd.read_csv(path + f'stats_tp_annual_{domain}_1901-2020_{model}.csv')

model=models[1]
tp_datasets[model] = {}
stats_datasets[model] = {}
for domain in domains:
    tp_datasets[model][domain] = pd.read_csv(path + f'timeseries_tp_annual_{domain}_1981-2025_{model}.csv')
    stats_datasets[model][domain] = pd.read_csv(path + f'stats_tp_annual_{domain}_1981-2025_{model}.csv')

model=models[5]
tp_datasets[model] = {}
stats_datasets[model] = {}
for domain in domains:
    tp_datasets[model][domain] = pd.read_csv(path + f'timeseries_tp_annual_{domain}_1980-2023_{model}.csv')
    stats_datasets[model][domain] = pd.read_csv(path + f'stats_tp_annual_{domain}_1980-2023_{model}.csv')

model=models[3]
tp_datasets[model] = {}
stats_datasets[model] = {}
for domain in domains:
    tp_datasets[model][domain] = pd.read_csv(path + f'timeseries_tp_annual_{domain}_1940-2025_{model}.csv')
    stats_datasets[model][domain] = pd.read_csv(path + f'stats_tp_annual_{domain}_1940-2025_{model}.csv')

# %%
resolutions = {'APHRO': '0.25°x0.25°',
               'GPCP': '1.0°x1.0°',
               'CRU': '0.5°x0.5°',
               'CHIRPS': '0.05°x0.05°',
               'HARv2': '10kmx10km',
               'ERA5': '0.25°x0.25°'}

#============== tableau des p-values ==========================

table = pd.DataFrame(index=models, columns=domains)
pvals = pd.DataFrame(index=models, columns=domains)

for model in models:
    for dom in domains:

        df = stats_datasets[model][dom]

        slope = df.loc[df['stat']=='slope','value'].values[0] * 10
        pval  = df.loc[df['stat']=='p_value','value'].values[0]

        table.loc[model, dom] = slope
        pvals.loc[model, dom] = pval

def bold_sig(val, p):
    if p < 0.05:
        return 'font-weight: bold'
    return ''

styled_table = table.style.apply(
    lambda x: [bold_sig(v, pvals.loc[x.name, col]) for col, v in x.items()],
    axis=1
).format("{:.2f}")

display(styled_table)

# ====================== plot time series ========================

fig, axes = plt.subplots(3, 2, figsize=(16,14))
axes = axes.flatten()

for i, dom in enumerate(domains):

    ax = axes[i]

    for model in models:
        da = tp_datasets[model][dom]
        ax.plot(da['year'], da['tp'], linestyle='-', label=f'{model} ({resolutions[model]})', linewidth=1.5)

    ax.set_title(dom, fontsize=16, weight="bold")
    
    if i in [0, 2, 4]:  # colonne gauche
        ax.set_ylabel('tp (mm month⁻¹)', fontsize=12)
    if i in [4, 5]:  # ligne du bas
        ax.tick_params(labelbottom=True)
    if i in [0,1,2,3]:
        ax.tick_params(labelbottom=False)
    
    ax.grid(True, linestyle='--', alpha=0.5)

handles, labels = axes[0].get_legend_handles_labels()
fig.legend(
    handles,
    labels,
    loc='lower center',
    bbox_to_anchor=(0.5, -0.04),
    ncol=3,
    fontsize=16,
    frameon=True
)
fig.suptitle(f'Annual Time series Precipitation (1891-2025)', fontsize=16, weight='bold')

plt.tight_layout(rect=[0,0.05,1,1])
plt.show()
# Out:
# <style type="text/css">
# #T_315e5_row0_col1, #T_315e5_row0_col5, #T_315e5_row1_col1, #T_315e5_row2_col1, #T_315e5_row2_col3, #T_315e5_row2_col4, #T_315e5_row2_col5, #T_315e5_row3_col0, #T_315e5_row3_col1, #T_315e5_row3_col3, #T_315e5_row3_col5, #T_315e5_row4_col1, #T_315e5_row4_col3, #T_315e5_row4_col4, #T_315e5_row5_col1, #T_315e5_row5_col3, #T_315e5_row5_col4 {
#   font-weight: bold;
# }
# </style>
# <table id="T_315e5">
#   <thead>
#     <tr>
#       <th class="blank level0" >&nbsp;</th>
#       <th id="T_315e5_level0_col0" class="col_heading level0 col0" >HMA</th>
#       <th id="T_315e5_level0_col1" class="col_heading level0 col1" >HK</th>
#       <th id="T_315e5_level0_col2" class="col_heading level0 col2" >SL</th>
#       <th id="T_315e5_level0_col3" class="col_heading level0 col3" >TP</th>
#       <th id="T_315e5_level0_col4" class="col_heading level0 col4" >CH</th>
#       <th id="T_315e5_level0_col5" class="col_heading level0 col5" >SEH</th>
#     </tr>
#   </thead>
# ...

# %% [markdown]
# # HMA domain

# %%
resolutions = {'APHRO': '0.25°x0.25°',
               'GPCP': '1.0°x1.0°',
               'CRU': '0.5°x0.5°',
               'CHIRPS': '0.05°x0.05°',
               'HARv2': '10kmx10km',
               'ERA5': '0.25°x0.25°'}

dom='HMA'

#============== tableau des p-values ==========================

table = pd.DataFrame(index=models, columns=domains)
pvals = pd.DataFrame(index=models, columns=domains)

for model in models:

    df = stats_datasets[model][dom]

    slope = df.loc[df['stat']=='slope','value'].values[0] * 10
    pval  = df.loc[df['stat']=='p_value','value'].values[0]

    table.loc[model, dom] = slope
    pvals.loc[model, dom] = pval

def bold_sig(val, p):
    if p < 0.05:
        return 'font-weight: bold'
    return ''

styled_table = table.style.apply(
    lambda x: [bold_sig(v, pvals.loc[x.name, col]) for col, v in x.items()],
    axis=1
).format("{:.2f}")

display(styled_table)

# ====================== plot time series ========================

fig, ax = plt.subplots(figsize=(16,10))
axes = axes.flatten()

for model in models:
    da = tp_datasets[model][dom]
    ax.plot(da['year'], da['tp'], linestyle='-', label=f'{model} ({resolutions[model]})', linewidth=1.5)

ax.set_title(dom, fontsize=16, weight="bold")
    
if i in [0, 2, 4]:  # colonne gauche
    ax.set_ylabel('tp (mm month⁻¹)', fontsize=12)
if i in [4, 5]:  # ligne du bas
    ax.tick_params(labelbottom=True)
if i in [0,1,2,3]:
    ax.tick_params(labelbottom=False)
    
ax.grid(True, linestyle='--', alpha=0.5)

handles, labels = ax.get_legend_handles_labels()
fig.legend(
    handles,
    labels,
    loc='lower center',
    bbox_to_anchor=(0.5, -0.04),
    ncol=3,
    fontsize=16,
    frameon=True
)
fig.suptitle(f'Annual Time series Precipitation (1891-2025)', fontsize=16, weight='bold')

plt.tight_layout(rect=[0,0.05,1,1])
plt.show()
# Out:
# <style type="text/css">
# #T_93858_row3_col0 {
#   font-weight: bold;
# }
# </style>
# <table id="T_93858">
#   <thead>
#     <tr>
#       <th class="blank level0" >&nbsp;</th>
#       <th id="T_93858_level0_col0" class="col_heading level0 col0" >HMA</th>
#       <th id="T_93858_level0_col1" class="col_heading level0 col1" >HK</th>
#       <th id="T_93858_level0_col2" class="col_heading level0 col2" >SL</th>
#       <th id="T_93858_level0_col3" class="col_heading level0 col3" >TP</th>
#       <th id="T_93858_level0_col4" class="col_heading level0 col4" >CH</th>
#       <th id="T_93858_level0_col5" class="col_heading level0 col5" >SEH</th>
#     </tr>
#   </thead>
#   <tbody>
#     <tr>
#       <th id="T_93858_level0_row0" class="row_heading level0 row0" >APHRO</th>
#       <td id="T_93858_row0_col0" class="data row0 col0" >0.38</td>
#       <td id="T_93858_row0_col1" class="data row0 col1" >nan</td>
#       <td id="T_93858_row0_col2" class="data row0 col2" >nan</td>
# ...

# %% [markdown]
# ## Changing the period :

# %%
tp_datasets = {}
stats_datasets = {}

domain = 'HMA'

path = '/bettik/PROJECTS/pr-regional-climate/bricej/results/timeseries/'

model=models[0]
tp_datasets[model] = {}
stats_datasets[model] = {}

tp_datasets[model][domain] = pd.read_csv(path + f'timeseries_tp_annual_{domain}_1951-2005_{model}.csv')
stats_datasets[model][domain] = pd.read_csv(path + f'stats_tp_annual_{domain}_1951-2005_{model}.csv')

model=models[4]
tp_datasets[model] = {}
stats_datasets[model] = {}
tp_datasets[model][domain] = pd.read_csv(path + f'timeseries_tp_annual_{domain}_1891-2019_{model}.csv')
stats_datasets[model][domain] = pd.read_csv(path + f'stats_tp_annual_{domain}_1891-2019_{model}.csv')

model=models[2]
tp_datasets[model] = {}
stats_datasets[model] = {}
tp_datasets[model][domain] = pd.read_csv(path + f'timeseries_tp_annual_{domain}_1901-2020_{model}.csv')
stats_datasets[model][domain] = pd.read_csv(path + f'stats_tp_annual_{domain}_1901-2020_{model}.csv')

model=models[1]
tp_datasets[model] = {}
stats_datasets[model] = {}
tp_datasets[model][domain] = pd.read_csv(path + f'timeseries_tp_annual_{domain}_1981-2024_{model}.csv')
stats_datasets[model][domain] = pd.read_csv(path + f'stats_tp_annual_{domain}_1981-2024_{model}.csv')

model=models[5]
tp_datasets[model] = {}
stats_datasets[model] = {}
tp_datasets[model][domain] = pd.read_csv(path + f'timeseries_tp_annual_{domain}_1980-2023_{model}.csv')
stats_datasets[model][domain] = pd.read_csv(path + f'stats_tp_annual_{domain}_1980-2023_{model}.csv')

model=models[3]
tp_datasets[model] = {}
stats_datasets[model] = {}
tp_datasets[model][domain] = pd.read_csv(path + f'timeseries_tp_annual_{domain}_1960-2025_{model}.csv')
stats_datasets[model][domain] = pd.read_csv(path + f'stats_tp_annual_{domain}_1960-2025_{model}.csv')

# %%
resolutions = {'APHRO': '0.25°x0.25°',
               'GPCP': '1.0°x1.0°',
               'CRU': '0.5°x0.5°',
               'CHIRPS': '0.05°x0.05°',
               'HARv2': '10kmx10km',
               'ERA5': '0.25°x0.25°'}

dom='HMA'

#============== tableau des p-values ==========================

cols = ['trend', 'std error', 'mean', 'std']
table = pd.DataFrame(index=models, columns=cols)
pvals = pd.Series(index=models)

for model in models:
    df = stats_datasets[model][dom]

    table.loc[model, 'trend'] = df.loc[df['stat']=='slope','value'].values[0] * 10
    table.loc[model, 'mean']  = df.loc[df['stat']=='mean','value'].values[0]
    table.loc[model, 'std']   = df.loc[df['stat']=='std','value'].values[0]
    table.loc[model, 'std error'] = df.loc[df['stat']=='std_err','value'].values[0]

    pvals.loc[model] = df.loc[df['stat']=='p_value','value'].values[0]

def bold_sig(val, p):
    if p < 0.05:
        return 'font-weight: bold'
    return ''

styled_table = table.style.apply(
    lambda x: [
        bold_sig(v, pvals.loc[x.name]) if col == 'trend' else ''
        for col, v in x.items()
    ],
    axis=1
).format("{:.2f}")

display(styled_table)

# ====================== plot time series ========================

fig, ax = plt.subplots(figsize=(16,10))
axes = axes.flatten()

for model in models:
    da = tp_datasets[model][dom]
    ax.plot(da['year'], da['tp'], linestyle='-', label=f'{model} ({resolutions[model]})', linewidth=1.5)

ax.set_title(dom, fontsize=16, weight="bold")
    
if i in [0, 2, 4]:  # colonne gauche
    ax.set_ylabel('tp (mm month⁻¹)', fontsize=12)
if i in [4, 5]:  # ligne du bas
    ax.tick_params(labelbottom=True)
if i in [0,1,2,3]:
    ax.tick_params(labelbottom=False)
    
ax.grid(True, linestyle='--', alpha=0.5)

handles, labels = ax.get_legend_handles_labels()
fig.legend(
    handles,
    labels,
    loc='lower center',
    bbox_to_anchor=(0.5, -0.04),
    ncol=3,
    fontsize=16,
    frameon=True
)
fig.suptitle(f'Annual Time series Precipitation (1891-2025)', fontsize=16, weight='bold')

plt.tight_layout(rect=[0,0.05,1,1])
plt.show()
# Out:
# <style type="text/css">
# #T_52b8a_row1_col0, #T_52b8a_row3_col0 {
#   font-weight: bold;
# }
# </style>
# <table id="T_52b8a">
#   <thead>
#     <tr>
#       <th class="blank level0" >&nbsp;</th>
#       <th id="T_52b8a_level0_col0" class="col_heading level0 col0" >trend</th>
#       <th id="T_52b8a_level0_col1" class="col_heading level0 col1" >std error</th>
#       <th id="T_52b8a_level0_col2" class="col_heading level0 col2" >mean</th>
#       <th id="T_52b8a_level0_col3" class="col_heading level0 col3" >std</th>
#     </tr>
#   </thead>
#   <tbody>
#     <tr>
#       <th id="T_52b8a_level0_row0" class="row_heading level0 row0" >APHRO</th>
#       <td id="T_52b8a_row0_col0" class="data row0 col0" >-0.26</td>
#       <td id="T_52b8a_row0_col1" class="data row0 col1" >0.02</td>
#       <td id="T_52b8a_row0_col2" class="data row0 col2" >43.38</td>
#       <td id="T_52b8a_row0_col3" class="data row0 col3" >2.12</td>
#     </tr>
#     <tr>
# ...

# %%
tp_datasets = {}
stats_datasets = {}

domain = 'HMA'

path = '/bettik/PROJECTS/pr-regional-climate/bricej/results/timeseries/'

model=models[0]
tp_datasets[model] = {}
stats_datasets[model] = {}

tp_datasets[model][domain] = pd.read_csv(path + f'timeseries_tp_annual_{domain}_1951-2015_{model}.csv')
stats_datasets[model][domain] = pd.read_csv(path + f'stats_tp_annual_{domain}_1951-2015_{model}.csv')

model=models[4]
tp_datasets[model] = {}
stats_datasets[model] = {}
tp_datasets[model][domain] = pd.read_csv(path + f'timeseries_tp_annual_{domain}_1891-2019_{model}.csv')
stats_datasets[model][domain] = pd.read_csv(path + f'stats_tp_annual_{domain}_1891-2019_{model}.csv')

model=models[2]
tp_datasets[model] = {}
stats_datasets[model] = {}
tp_datasets[model][domain] = pd.read_csv(path + f'timeseries_tp_annual_{domain}_1901-2020_{model}.csv')
stats_datasets[model][domain] = pd.read_csv(path + f'stats_tp_annual_{domain}_1901-2020_{model}.csv')

model=models[1]
tp_datasets[model] = {}
stats_datasets[model] = {}
tp_datasets[model][domain] = pd.read_csv(path + f'timeseries_tp_annual_{domain}_1981-2024_{model}.csv')
stats_datasets[model][domain] = pd.read_csv(path + f'stats_tp_annual_{domain}_1981-2024_{model}.csv')

model=models[5]
tp_datasets[model] = {}
stats_datasets[model] = {}
tp_datasets[model][domain] = pd.read_csv(path + f'timeseries_tp_annual_{domain}_1980-2023_{model}.csv')
stats_datasets[model][domain] = pd.read_csv(path + f'stats_tp_annual_{domain}_1980-2023_{model}.csv')

model=models[3]
tp_datasets[model] = {}
stats_datasets[model] = {}
tp_datasets[model][domain] = pd.read_csv(path + f'timeseries_tp_annual_{domain}_1940-2025_{model}.csv')
stats_datasets[model][domain] = pd.read_csv(path + f'stats_tp_annual_{domain}_1940-2025_{model}.csv')

# %%
resolutions = {'APHRO': '0.25°x0.25°',
               'GPCP': '1.0°x1.0°',
               'CRU': '0.5°x0.5°',
               'CHIRPS': '0.05°x0.05°',
               'HARv2': '10kmx10km',
               'ERA5': '0.25°x0.25°'}

dom='HMA'

#============== tableau des p-values ==========================

cols = ['trend', 'std error', 'mean', 'std']
table = pd.DataFrame(index=models, columns=cols)
pvals = pd.Series(index=models)

for model in models:
    df = stats_datasets[model][dom]

    table.loc[model, 'trend'] = df.loc[df['stat']=='slope','value'].values[0] * 10
    table.loc[model, 'mean']  = df.loc[df['stat']=='mean','value'].values[0]
    table.loc[model, 'std']   = df.loc[df['stat']=='std','value'].values[0]
    table.loc[model, 'std error'] = df.loc[df['stat']=='std_err','value'].values[0]

    pvals.loc[model] = df.loc[df['stat']=='p_value','value'].values[0]

def bold_sig(val, p):
    if p < 0.05:
        return 'font-weight: bold'
    return ''

styled_table = table.style.apply(
    lambda x: [
        bold_sig(v, pvals.loc[x.name]) if col == 'trend' else ''
        for col, v in x.items()
    ],
    axis=1
).format("{:.2f}")

display(styled_table)

# ====================== plot time series ========================

fig, ax = plt.subplots(figsize=(12,8))
axes = axes.flatten()

for model in models:
    da = tp_datasets[model][dom]

    if model == 'APHRO':
        ax.plot(da['year'], da['tp'], linestyle='-', label=f'{model} ({resolutions[model]})', linewidth=2, zorder=10)
    else:
        ax.plot(da['year'], da['tp'], linestyle='-', label=f'{model} ({resolutions[model]})', linewidth=2, zorder=2)

    if model == 'ERA5':
        imax = np.argmax(da['tp'])
        imin = np.argmin(da['tp'])
        ax.scatter(da['year'][imax], da['tp'][imax], color='tab:red', s=80, edgecolor='black', zorder=10)
        ax.scatter(da['year'][imin], da['tp'][imin], color='tab:red', s=80, edgecolor='black', zorder=10)

ax.set_title(dom, fontsize=16, weight="bold")
ax.set_ylabel('tp (mm month⁻¹)', fontsize=16)


ax.tick_params(labelbottom=True, labelsize=16)
    
ax.grid(True, linestyle='--', alpha=0.5)

ax.axvspan(1981,2015,color='lightgray',alpha=0.8,zorder=0,ec=None)

handles, labels = ax.get_legend_handles_labels()
fig.legend(
    handles,
    labels,
    loc='lower center',
    bbox_to_anchor=(0.5, -0.04),
    ncol=3,
    fontsize=16,
    frameon=True
)
fig.suptitle(f'Annual Time series Precipitation (1891-2025)', fontsize=16, weight='bold')

plt.tight_layout(rect=[0,0.08,1,1]) # [left, bottom, right, top]
plt.show()
# Out:
# <style type="text/css">
# #T_35f33_row1_col0, #T_35f33_row3_col0 {
#   font-weight: bold;
# }
# </style>
# <table id="T_35f33">
#   <thead>
#     <tr>
#       <th class="blank level0" >&nbsp;</th>
#       <th id="T_35f33_level0_col0" class="col_heading level0 col0" >trend</th>
#       <th id="T_35f33_level0_col1" class="col_heading level0 col1" >std error</th>
#       <th id="T_35f33_level0_col2" class="col_heading level0 col2" >mean</th>
#       <th id="T_35f33_level0_col3" class="col_heading level0 col3" >std</th>
#     </tr>
#   </thead>
#   <tbody>
#     <tr>
#       <th id="T_35f33_level0_row0" class="row_heading level0 row0" >APHRO</th>
#       <td id="T_35f33_row0_col0" class="data row0 col0" >0.38</td>
#       <td id="T_35f33_row0_col1" class="data row0 col1" >0.02</td>
#       <td id="T_35f33_row0_col2" class="data row0 col2" >43.99</td>
#       <td id="T_35f33_row0_col3" class="data row0 col3" >3.21</td>
#     </tr>
#     <tr>
# ...

# %% [markdown]
# # Cohérence

# %%
for model in models:
    tp_datasets[model]['HMA'] = tp_datasets[model]['HMA'][tp_datasets[model]['HMA']['year'].between(1981, 2010)]

# %%
domain = 'HMA'
ref_model = 'ERA5'

coherence = pd.DataFrame(index=models, columns=['coherence'], dtype=float)

# référence
ref_df = tp_datasets[ref_model][domain][['year', 'tp']]

for model in models:
    df = tp_datasets[model][domain][['year', 'tp']]

    # merge sur les années communes
    merged = pd.merge(
        ref_df,
        df,
        on='year',
        suffixes=('_ref', '_model')
    ).dropna()
    
    # corrélation (Pearson)
    corr = merged['tp_ref'].corr(merged['tp_model'])

    coherence.loc[model, 'coherence'] = corr

display(coherence.style.format("{:.2f}"))
# Out:
# <style type="text/css">
# </style>
# <table id="T_6c68b">
#   <thead>
#     <tr>
#       <th class="blank level0" >&nbsp;</th>
#       <th id="T_6c68b_level0_col0" class="col_heading level0 col0" >coherence</th>
#     </tr>
#   </thead>
#   <tbody>
#     <tr>
#       <th id="T_6c68b_level0_row0" class="row_heading level0 row0" >APHRO</th>
#       <td id="T_6c68b_row0_col0" class="data row0 col0" >0.84</td>
#     </tr>
#     <tr>
#       <th id="T_6c68b_level0_row1" class="row_heading level0 row1" >CHIRPS</th>
#       <td id="T_6c68b_row1_col0" class="data row1 col0" >0.46</td>
#     </tr>
#     <tr>
#       <th id="T_6c68b_level0_row2" class="row_heading level0 row2" >CRU</th>
#       <td id="T_6c68b_row2_col0" class="data row2 col0" >0.80</td>
#     </tr>
#     <tr>
#       <th id="T_6c68b_level0_row3" class="row_heading level0 row3" >ERA5</th>
#       <td id="T_6c68b_row3_col0" class="data row3 col0" >1.00</td>
#     </tr>
#     <tr>
# ...

# %%
for model in models:
    tp_datasets[model]['HMA'] = tp_datasets[model]['HMA'][tp_datasets[model]['HMA']['year'].between(1981, 2019)]

# %%
domain = 'HMA'
ref_model = 'ERA5'

coherence = pd.DataFrame(index=models, columns=['coherence'], dtype=float)

# référence
ref_df = tp_datasets[ref_model][domain][['year', 'tp']]

for model in models:
    df = tp_datasets[model][domain][['year', 'tp']]

    # merge sur les années communes
    merged = pd.merge(
        ref_df,
        df,
        on='year',
        suffixes=('_ref', '_model')
    ).dropna()
    
    # corrélation (Pearson)
    corr = merged['tp_ref'].corr(merged['tp_model'])

    coherence.loc[model, 'coherence'] = corr

display(coherence.style.format("{:.2f}"))
# Out:
# <style type="text/css">
# </style>
# <table id="T_86d22">
#   <thead>
#     <tr>
#       <th class="blank level0" >&nbsp;</th>
#       <th id="T_86d22_level0_col0" class="col_heading level0 col0" >coherence</th>
#     </tr>
#   </thead>
#   <tbody>
#     <tr>
#       <th id="T_86d22_level0_row0" class="row_heading level0 row0" >APHRO</th>
#       <td id="T_86d22_row0_col0" class="data row0 col0" >0.84</td>
#     </tr>
#     <tr>
#       <th id="T_86d22_level0_row1" class="row_heading level0 row1" >CHIRPS</th>
#       <td id="T_86d22_row1_col0" class="data row1 col0" >0.46</td>
#     </tr>
#     <tr>
#       <th id="T_86d22_level0_row2" class="row_heading level0 row2" >CRU</th>
#       <td id="T_86d22_row2_col0" class="data row2 col0" >0.80</td>
#     </tr>
#     <tr>
#       <th id="T_86d22_level0_row3" class="row_heading level0 row3" >ERA5</th>
#       <td id="T_86d22_row3_col0" class="data row3 col0" >1.00</td>
#     </tr>
#     <tr>
# ...

# %%
for model in models:
    tp_datasets[model]['HMA'] = tp_datasets[model]['HMA'][tp_datasets[model]['HMA']['year'].between(1981, 2015)]

# %%
domain = 'HMA'
ref_model = 'ERA5'

coherence = pd.DataFrame(index=models, columns=['coherence'], dtype=float)

# référence
ref_df = tp_datasets[ref_model][domain][['year', 'tp']]

for model in models:
    df = tp_datasets[model][domain][['year', 'tp']]

    # merge sur les années communes
    merged = pd.merge(
        ref_df,
        df,
        on='year',
        suffixes=('_ref', '_model')
    ).dropna()
    
    # corrélation (Pearson)
    corr = merged['tp_ref'].corr(merged['tp_model'])

    coherence.loc[model, 'coherence'] = corr

display(coherence.style.format("{:.2f}"))
# Out:
# <style type="text/css">
# </style>
# <table id="T_c2ed4">
#   <thead>
#     <tr>
#       <th class="blank level0" >&nbsp;</th>
#       <th id="T_c2ed4_level0_col0" class="col_heading level0 col0" >coherence</th>
#     </tr>
#   </thead>
#   <tbody>
#     <tr>
#       <th id="T_c2ed4_level0_row0" class="row_heading level0 row0" >APHRO</th>
#       <td id="T_c2ed4_row0_col0" class="data row0 col0" >0.84</td>
#     </tr>
#     <tr>
#       <th id="T_c2ed4_level0_row1" class="row_heading level0 row1" >CHIRPS</th>
#       <td id="T_c2ed4_row1_col0" class="data row1 col0" >0.46</td>
#     </tr>
#     <tr>
#       <th id="T_c2ed4_level0_row2" class="row_heading level0 row2" >CRU</th>
#       <td id="T_c2ed4_row2_col0" class="data row2 col0" >0.80</td>
#     </tr>
#     <tr>
#       <th id="T_c2ed4_level0_row3" class="row_heading level0 row3" >ERA5</th>
#       <td id="T_c2ed4_row3_col0" class="data row3 col0" >1.00</td>
#     </tr>
#     <tr>
# ...

# %% [markdown]
# # RMSE with ERA5

# %%
for model in models:
    tp_datasets[model]['HMA'] = tp_datasets[model]['HMA'][tp_datasets[model]['HMA']['year'].between(1981, 2015)].reset_index(drop=True)

# %%
era5 = tp_datasets['ERA5']['HMA'][['year', 'tp']]
rmse = pd.DataFrame(index=models, columns=['rmse'], dtype=float)

for model in models:
    df = tp_datasets[model]['HMA'][['year', 'tp']]

    diff = (df['tp'] - era5['tp'])**2
    sum_diff = np.sum(diff)
    rmse_model = np.sqrt(sum_diff/35)

    rmse.loc[model,'rmse'] = rmse_model

# %%
display(rmse.style.format("{:.2f}"))
# Out:
# <style type="text/css">
# </style>
# <table id="T_e7627">
#   <thead>
#     <tr>
#       <th class="blank level0" >&nbsp;</th>
#       <th id="T_e7627_level0_col0" class="col_heading level0 col0" >rmse</th>
#     </tr>
#   </thead>
#   <tbody>
#     <tr>
#       <th id="T_e7627_level0_row0" class="row_heading level0 row0" >APHRO</th>
#       <td id="T_e7627_row0_col0" class="data row0 col0" >22.40</td>
#     </tr>
#     <tr>
#       <th id="T_e7627_level0_row1" class="row_heading level0 row1" >CHIRPS</th>
#       <td id="T_e7627_row1_col0" class="data row1 col0" >16.26</td>
#     </tr>
#     <tr>
#       <th id="T_e7627_level0_row2" class="row_heading level0 row2" >CRU</th>
#       <td id="T_e7627_row2_col0" class="data row2 col0" >16.61</td>
#     </tr>
#     <tr>
#       <th id="T_e7627_level0_row3" class="row_heading level0 row3" >ERA5</th>
#       <td id="T_e7627_row3_col0" class="data row3 col0" >0.00</td>
#     </tr>
#     <tr>
# ...

# %%
era5 = tp_datasets['ERA5']['HMA'][['year', 'tp']]
bias = pd.DataFrame(index=models, columns=['bias'], dtype=float)

for model in models:
    df = tp_datasets[model]['HMA'][['year', 'tp']]

    diff = df['tp'] - era5['tp']
    mean_diff = np.mean(diff)

    bias.loc[model,'bias'] = mean_diff

# %%
display(bias.style.format("{:.2f}"))
# Out:
# <style type="text/css">
# </style>
# <table id="T_72397">
#   <thead>
#     <tr>
#       <th class="blank level0" >&nbsp;</th>
#       <th id="T_72397_level0_col0" class="col_heading level0 col0" >bias</th>
#     </tr>
#   </thead>
#   <tbody>
#     <tr>
#       <th id="T_72397_level0_row0" class="row_heading level0 row0" >APHRO</th>
#       <td id="T_72397_row0_col0" class="data row0 col0" >-24.14</td>
#     </tr>
#     <tr>
#       <th id="T_72397_level0_row1" class="row_heading level0 row1" >CHIRPS</th>
#       <td id="T_72397_row1_col0" class="data row1 col0" >-17.35</td>
#     </tr>
#     <tr>
#       <th id="T_72397_level0_row2" class="row_heading level0 row2" >CRU</th>
#       <td id="T_72397_row2_col0" class="data row2 col0" >-17.86</td>
#     </tr>
#     <tr>
#       <th id="T_72397_level0_row3" class="row_heading level0 row3" >ERA5</th>
#       <td id="T_72397_row3_col0" class="data row3 col0" >0.00</td>
#     </tr>
#     <tr>
# ...
