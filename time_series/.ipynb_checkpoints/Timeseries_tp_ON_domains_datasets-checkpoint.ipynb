# %%
import sys
sys.path.insert(1, '/home/bricej/MyPythonLibrary/StageM2_IVT/library/')
import domain
from domain import *
from climbas import *
import numpy as np
import xarray as xr
import pandas as pd
from netCDF4 import Dataset
from scipy import stats
import scipy.stats as stats
import matplotlib.pyplot as plt

# %% [markdown]
# # Period

# %%
iyear = 1981
fyear = 2015
models = ['APHRO','GPCP','CRU','CHIRPS','HARv2','ERA5']
domains = ['HMA','HK','SL','TP','CH','SEH']

# %% [markdown]
# # TP timeseries DATASETS & DOMAINS

# %% [markdown]
# ## DJFM

# %%
tp_datasets = {}
stats_datasets = {}

path = '/bettik/PROJECTS/pr-regional-climate/bricej/results/timeseries/'

for model in models:
    tp_datasets[model] = {}
    stats_datasets[model] = {}
    for domain in domains:
        tp_datasets[model][domain] = pd.read_csv(path + f'timeseries_tp_ON_{domain}_1981-2015_{model}.csv')
        stats_datasets[model][domain] = pd.read_csv(path + f'stats_tp_ON_{domain}_1981-2015_{model}.csv')

# %%
resolutions = {'APHRO': '0.25°x0.25°',
               'GPCP': '1.0°x1.0°',
               'CRU': '0.5°x0.5°',
               'CHIRPS': '0.05°x0.05°',
               'HARv2': '10kmx10km',
               'ERA5': '0.25°x0.25°'}

#============== tableau des p-values ==========================

table = pd.DataFrame(index=models, columns=domains)
pvals = pd.DataFrame(index=models, columns=domains)

for model in models:
    for dom in domains:

        df = stats_datasets[model][dom]

        slope = df.loc[df['stat']=='slope','value'].values[0] * 10
        pval  = df.loc[df['stat']=='p_value','value'].values[0]

        table.loc[model, dom] = slope
        pvals.loc[model, dom] = pval

def bold_sig(val, p):
    if p < 0.05:
        return 'font-weight: bold'
    return ''

styled_table = table.style.apply(
    lambda x: [bold_sig(v, pvals.loc[x.name, col]) for col, v in x.items()],
    axis=1
).format("{:.2f}")

display(styled_table)

# ====================== plot time series ========================

fig, axes = plt.subplots(3, 2, figsize=(16,14))
axes = axes.flatten()

for i, dom in enumerate(domains):

    ax = axes[i]

    for model in models:
        da = tp_datasets[model][dom]
        ax.plot(da['year'], da['tp'], linestyle='-', label=f'{model} ({resolutions[model]})', linewidth=1.5)

    ax.set_title(dom, fontsize=16, weight="bold")
    
    if i in [0, 2, 4]:  # colonne gauche
        ax.set_ylabel('tp (mm month⁻¹)', fontsize=12)
    if i in [4, 5]:  # ligne du bas
        ax.tick_params(labelbottom=True)
    if i in [0,1,2,3]:
        ax.tick_params(labelbottom=False)
    
    ax.grid(True, linestyle='--', alpha=0.5)

handles, labels = axes[0].get_legend_handles_labels()
fig.legend(
    handles,
    labels,
    loc='lower center',
    bbox_to_anchor=(0.5, -0.04),
    ncol=3,
    fontsize=16,
    frameon=True
)
fig.suptitle(f'ON Time series Precipitation ({iyear}-{fyear})', fontsize=16, weight='bold')

plt.tight_layout(rect=[0,0.05,1,1])
plt.show()
# Out:
# <style type="text/css">
# #T_a28cd_row0_col1, #T_a28cd_row3_col3, #T_a28cd_row5_col5 {
#   font-weight: bold;
# }
# </style>
# <table id="T_a28cd">
#   <thead>
#     <tr>
#       <th class="blank level0" >&nbsp;</th>
#       <th id="T_a28cd_level0_col0" class="col_heading level0 col0" >HMA</th>
#       <th id="T_a28cd_level0_col1" class="col_heading level0 col1" >HK</th>
#       <th id="T_a28cd_level0_col2" class="col_heading level0 col2" >SL</th>
#       <th id="T_a28cd_level0_col3" class="col_heading level0 col3" >TP</th>
#       <th id="T_a28cd_level0_col4" class="col_heading level0 col4" >CH</th>
#       <th id="T_a28cd_level0_col5" class="col_heading level0 col5" >SEH</th>
#     </tr>
#   </thead>
#   <tbody>
#     <tr>
#       <th id="T_a28cd_level0_row0" class="row_heading level0 row0" >APHRO</th>
#       <td id="T_a28cd_row0_col0" class="data row0 col0" >0.96</td>
#       <td id="T_a28cd_row0_col1" class="data row0 col1" >7.70</td>
#       <td id="T_a28cd_row0_col2" class="data row0 col2" >-1.21</td>
#       <td id="T_a28cd_row0_col3" class="data row0 col3" >0.41</td>
#       <td id="T_a28cd_row0_col4" class="data row0 col4" >-0.05</td>
#       <td id="T_a28cd_row0_col5" class="data row0 col5" >-3.17</td>
#     </tr>
#     <tr>
#       <th id="T_a28cd_level0_row1" class="row_heading level0 row1" >GPCP</th>
#       <td id="T_a28cd_row1_col0" class="data row1 col0" >-0.24</td>
#       <td id="T_a28cd_row1_col1" class="data row1 col1" >2.56</td>
#       <td id="T_a28cd_row1_col2" class="data row1 col2" >-2.81</td>
#       <td id="T_a28cd_row1_col3" class="data row1 col3" >0.39</td>
#       <td id="T_a28cd_row1_col4" class="data row1 col4" >-0.46</td>
#       <td id="T_a28cd_row1_col5" class="data row1 col5" >-3.78</td>
#     </tr>
#     <tr>
#       <th id="T_a28cd_level0_row2" class="row_heading level0 row2" >CRU</th>
#       <td id="T_a28cd_row2_col0" class="data row2 col0" >0.07</td>
#       <td id="T_a28cd_row2_col1" class="data row2 col1" >1.07</td>
#       <td id="T_a28cd_row2_col2" class="data row2 col2" >-1.41</td>
#       <td id="T_a28cd_row2_col3" class="data row2 col3" >0.38</td>
#       <td id="T_a28cd_row2_col4" class="data row2 col4" >-0.63</td>
#       <td id="T_a28cd_row2_col5" class="data row2 col5" >-0.61</td>
#     </tr>
#     <tr>
#       <th id="T_a28cd_level0_row3" class="row_heading level0 row3" >CHIRPS</th>
#       <td id="T_a28cd_row3_col0" class="data row3 col0" >0.71</td>
#       <td id="T_a28cd_row3_col1" class="data row3 col1" >2.36</td>
#       <td id="T_a28cd_row3_col2" class="data row3 col2" >-0.37</td>
#       <td id="T_a28cd_row3_col3" class="data row3 col3" >0.47</td>
#       <td id="T_a28cd_row3_col4" class="data row3 col4" >1.83</td>
#       <td id="T_a28cd_row3_col5" class="data row3 col5" >-0.58</td>
#     </tr>
#     <tr>
#       <th id="T_a28cd_level0_row4" class="row_heading level0 row4" >HARv2</th>
#       <td id="T_a28cd_row4_col0" class="data row4 col0" >0.04</td>
#       <td id="T_a28cd_row4_col1" class="data row4 col1" >1.59</td>
#       <td id="T_a28cd_row4_col2" class="data row4 col2" >-1.61</td>
#       <td id="T_a28cd_row4_col3" class="data row4 col3" >0.67</td>
#       <td id="T_a28cd_row4_col4" class="data row4 col4" >3.18</td>
#       <td id="T_a28cd_row4_col5" class="data row4 col5" >-5.05</td>
#     </tr>
#     <tr>
#       <th id="T_a28cd_level0_row5" class="row_heading level0 row5" >ERA5</th>
#       <td id="T_a28cd_row5_col0" class="data row5 col0" >-1.08</td>
#       <td id="T_a28cd_row5_col1" class="data row5 col1" >0.15</td>
#       <td id="T_a28cd_row5_col2" class="data row5 col2" >-0.99</td>
#       <td id="T_a28cd_row5_col3" class="data row5 col3" >0.52</td>
#       <td id="T_a28cd_row5_col4" class="data row5 col4" >3.31</td>
#       <td id="T_a28cd_row5_col5" class="data row5 col5" >-9.31</td>
#     </tr>
#   </tbody>
# </table>

# %% [markdown]
# ## BOX PLOT

# %%
fig, axes = plt.subplots(3, 2, figsize=(16,14))
axes = axes.flatten()

for i, dom in enumerate(domains):
    ax = axes[i]

    data_to_plot = []
    labels_to_plot = []

    for model in models:
        da = tp_datasets[model][dom]['tp']
        data_to_plot.append(da.values)
        labels_to_plot.append(model)

    # créer le boxplot
    bp = ax.boxplot(data_to_plot, tick_labels=labels_to_plot, patch_artist=False)

    # axes et style
    if i in [0, 2, 4]:
        ax.set_ylabel('tp (mm month⁻¹)', fontsize=12)
    if i in [4, 5]:
        ax.tick_params(labelbottom=True)
        ax.tick_params(axis='x', labelsize=20)
    if i in [0,1,2,3]:
        ax.tick_params(labelbottom=False)

    ax.set_title(dom, fontsize=16, weight='bold')
    ax.grid(True, linestyle='--', alpha=0.5, axis='y')
    ax.tick_params(axis='x', rotation=45)

fig.suptitle(f'ON Precipitation Distribution ({iyear}-{fyear})', fontsize=16, weight='bold')
plt.tight_layout(rect=[0,0.03,1,0.95])
fig.subplots_adjust(top=0.93) 
plt.show()

# %% [markdown]
# # Trend plot

# %%
fig, axes = plt.subplots(3, 2, figsize=(16,14))
axes = axes.flatten()

colors = {'APHRO':'blue', 'GPCP':'orange', 'CRU':'green',
          'CHIRPS':'red', 'HARv2':'purple', 'ERA5':'brown'}

for i, dom in enumerate(domains):
    ax = axes[i]

    x = range(1, len(models)+1)
    slopes = []
    errors = []

    for xi, model in zip(x, models):
        df = stats_datasets[model][dom]
        slope = df.loc[df['stat']=='slope', 'value'].values[0] *10
        std_err = df.loc[df['stat']=='std_err', 'value'].values[0] *10
        p_value = df.loc[df['stat']=='p_value', 'value'].values[0]

        if p_value <= 0.05:
            # plot point + barre d'erreur
            ax.errorbar(xi, slope, yerr=std_err, fmt='o', color=colors[model],
                        ecolor=colors[model], elinewidth=2, capsize=5, markersize=8)
        else:
            ax.errorbar(xi, slope, yerr=std_err, fmt='o', color='black',
                        ecolor='black', elinewidth=2, capsize=5, markersize=8, alpha=0.5)

    # axes et style
    if i in [0, 2, 4]:
        ax.set_ylabel('tp trend (mm/month/decade)', fontsize=12)
    if i in [4, 5]:
        ax.set_xticks(x)
        ax.set_xticklabels(models, rotation=45, fontsize=16)
    if i in [0,1,2,3]:
        ax.tick_params(labelbottom=False)

    ax.set_title(dom, fontsize=16, weight='bold')
    ax.grid(True, linestyle='--', alpha=0.5, axis='y')

fig.suptitle(f'ON Precipitation Trends ({iyear}-{fyear})', fontsize=16, weight='bold')
plt.tight_layout(rect=[0,0.03,1,0.95])
fig.subplots_adjust(top=0.93)
plt.show()
