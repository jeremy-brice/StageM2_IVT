# %%
import sys
sys.path.insert(1, '/home/bricej/MyPythonLibrary/StageM2_IVT/library/')
import domain
from domain import *
from climbas import *
import numpy as np
import xarray as xr
import pandas as pd
from netCDF4 import Dataset
from scipy import stats
import scipy.stats as stats
import matplotlib.pyplot as plt

# %% [markdown]
# # Models & Domains

# %%
models = ['APHRO','GPCP','CRU','CHIRPS','HARv2','ERA5']
domains = ['HMA','HK','SL','TP','CH','SEH']

# %% [markdown]
# # TP timeseries DATASETS & DOMAINS

# %% [markdown]
# ## Annual

# %%
tp_datasets = {}
stats_datasets = {}

periods = {'APHRO': '1951-2005',
          'GPCP': '1891-2019',
          'CRU': '1901-2020',
          'CHIRPS': '1981-2024',
          'HARv2': '1980-2023',
          'ERA5': '1960-2025'}

path = '/bettik/PROJECTS/pr-regional-climate/bricej/results/timeseries/'

for model in models:
    tp_datasets[model] = {}
    stats_datasets[model] = {}
    for domain in domains:
        tp_datasets[model][domain] = pd.read_csv(path + f'timeseries_tp_annual_{domain}_{periods[model]}_{model}.csv')
        stats_datasets[model][domain] = pd.read_csv(path + f'stats_tp_annual_{domain}_{periods[model]}_{model}.csv')

# %%
resolutions = {'APHRO': '0.25°x0.25°',
               'GPCP': '1.0°x1.0°',
               'CRU': '0.5°x0.5°',
               'CHIRPS': '0.05°x0.05°',
               'HARv2': '10kmx10km',
               'ERA5': '0.25°x0.25°'}

#============== tableau des p-values ==========================

table = pd.DataFrame(index=models, columns=domains)
pvals = pd.DataFrame(index=models, columns=domains)

for model in models:
    for dom in domains:

        df = stats_datasets[model][dom]

        slope = df.loc[df['stat']=='slope','value'].values[0] * 10
        pval  = df.loc[df['stat']=='p_value','value'].values[0]

        table.loc[model, dom] = slope
        pvals.loc[model, dom] = pval

def bold_sig(val, p):
    if p < 0.05:
        return 'font-weight: bold'
    return ''

styled_table = table.style.apply(
    lambda x: [bold_sig(v, pvals.loc[x.name, col]) for col, v in x.items()],
    axis=1
).format("{:.2f}")

display(styled_table)

# ====================== plot time series ========================

fig, axes = plt.subplots(3, 2, figsize=(16,14))
axes = axes.flatten()

for i, dom in enumerate(domains):

    ax = axes[i]

    for model in models:
        da = tp_datasets[model][dom]
        ax.plot(da['year'], da['tp'], linestyle='-', label=f'{model} ({resolutions[model]}) ({periods[model]})', linewidth=1.5)

    ax.set_title(dom, fontsize=16, weight="bold")
    
    if i in [0, 2, 4]:  # colonne gauche
        ax.set_ylabel('tp (mm month⁻¹)', fontsize=12)
    if i in [4, 5]:  # ligne du bas
        ax.tick_params(labelbottom=True)
    if i in [0,1,2,3]:
        ax.tick_params(labelbottom=False)
    
    ax.grid(True, linestyle='--', alpha=0.5)

handles, labels = axes[0].get_legend_handles_labels()
fig.legend(
    handles,
    labels,
    loc='lower center',
    bbox_to_anchor=(0.5, -0.04),
    ncol=3,
    fontsize=16,
    frameon=True
)
fig.suptitle(f'Annual Time series Precipitation', fontsize=16, weight='bold')

plt.tight_layout(rect=[0,0.05,1,1])
plt.show()
# Out:
# <style type="text/css">
# #T_89c37_row0_col2, #T_89c37_row0_col5, #T_89c37_row1_col1, #T_89c37_row1_col3, #T_89c37_row1_col4, #T_89c37_row2_col1, #T_89c37_row2_col3, #T_89c37_row2_col4, #T_89c37_row2_col5, #T_89c37_row3_col0, #T_89c37_row3_col3, #T_89c37_row4_col1, #T_89c37_row4_col3, #T_89c37_row4_col4, #T_89c37_row5_col0, #T_89c37_row5_col3, #T_89c37_row5_col5 {
#   font-weight: bold;
# }
# </style>
# <table id="T_89c37">
#   <thead>
#     <tr>
#       <th class="blank level0" >&nbsp;</th>
#       <th id="T_89c37_level0_col0" class="col_heading level0 col0" >HMA</th>
#       <th id="T_89c37_level0_col1" class="col_heading level0 col1" >HK</th>
#       <th id="T_89c37_level0_col2" class="col_heading level0 col2" >SL</th>
#       <th id="T_89c37_level0_col3" class="col_heading level0 col3" >TP</th>
#       <th id="T_89c37_level0_col4" class="col_heading level0 col4" >CH</th>
#       <th id="T_89c37_level0_col5" class="col_heading level0 col5" >SEH</th>
#     </tr>
#   </thead>
# ...

# %% [markdown]
# # DJFM

# %%
tp_datasets = {}
stats_datasets = {}

periods = {'APHRO': '1951-2005',
          'GPCP': '1891-2019',
          'CRU': '1901-2020',
          'CHIRPS': '1981-2024',
          'HARv2': '1980-2023',
          'ERA5': '1960-2025'}

path = '/bettik/PROJECTS/pr-regional-climate/bricej/results/timeseries/'

for model in models:
    tp_datasets[model] = {}
    stats_datasets[model] = {}
    for domain in domains:
        tp_datasets[model][domain] = pd.read_csv(path + f'timeseries_tp_DJFM_{domain}_{periods[model]}_{model}.csv')
        stats_datasets[model][domain] = pd.read_csv(path + f'stats_tp_DJFM_{domain}_{periods[model]}_{model}.csv')

# %%
resolutions = {'APHRO': '0.25°x0.25°',
               'GPCP': '1.0°x1.0°',
               'CRU': '0.5°x0.5°',
               'CHIRPS': '0.05°x0.05°',
               'HARv2': '10kmx10km',
               'ERA5': '0.25°x0.25°'}

#============== tableau des p-values ==========================

table = pd.DataFrame(index=models, columns=domains)
pvals = pd.DataFrame(index=models, columns=domains)

for model in models:
    for dom in domains:

        df = stats_datasets[model][dom]

        slope = df.loc[df['stat']=='slope','value'].values[0] * 10
        pval  = df.loc[df['stat']=='p_value','value'].values[0]

        table.loc[model, dom] = slope
        pvals.loc[model, dom] = pval

def bold_sig(val, p):
    if p < 0.05:
        return 'font-weight: bold'
    return ''

styled_table = table.style.apply(
    lambda x: [bold_sig(v, pvals.loc[x.name, col]) for col, v in x.items()],
    axis=1
).format("{:.2f}")

display(styled_table)

# ====================== plot time series ========================

fig, axes = plt.subplots(3, 2, figsize=(16,14))
axes = axes.flatten()

for i, dom in enumerate(domains):

    ax = axes[i]

    for model in models:
        da = tp_datasets[model][dom]
        ax.plot(da['year'], da['tp'], linestyle='-', label=f'{model} ({resolutions[model]}) ({periods[model]})', linewidth=1.5)

    ax.set_title(dom, fontsize=16, weight="bold")
    
    if i in [0, 2, 4]:  # colonne gauche
        ax.set_ylabel('tp (mm month⁻¹)', fontsize=12)
    if i in [4, 5]:  # ligne du bas
        ax.tick_params(labelbottom=True)
    if i in [0,1,2,3]:
        ax.tick_params(labelbottom=False)
    
    ax.grid(True, linestyle='--', alpha=0.5)

handles, labels = axes[0].get_legend_handles_labels()
fig.legend(
    handles,
    labels,
    loc='lower center',
    bbox_to_anchor=(0.5, -0.04),
    ncol=3,
    fontsize=16,
    frameon=True
)
fig.suptitle(f'DJFM Time series Precipitation', fontsize=16, weight='bold')

plt.tight_layout(rect=[0,0.05,1,1])
plt.show()
# Out:
# <style type="text/css">
# #T_cd9e3_row0_col2, #T_cd9e3_row0_col3, #T_cd9e3_row1_col3, #T_cd9e3_row2_col1, #T_cd9e3_row4_col0, #T_cd9e3_row4_col1 {
#   font-weight: bold;
# }
# </style>
# <table id="T_cd9e3">
#   <thead>
#     <tr>
#       <th class="blank level0" >&nbsp;</th>
#       <th id="T_cd9e3_level0_col0" class="col_heading level0 col0" >HMA</th>
#       <th id="T_cd9e3_level0_col1" class="col_heading level0 col1" >HK</th>
#       <th id="T_cd9e3_level0_col2" class="col_heading level0 col2" >SL</th>
#       <th id="T_cd9e3_level0_col3" class="col_heading level0 col3" >TP</th>
#       <th id="T_cd9e3_level0_col4" class="col_heading level0 col4" >CH</th>
#       <th id="T_cd9e3_level0_col5" class="col_heading level0 col5" >SEH</th>
#     </tr>
#   </thead>
#   <tbody>
#     <tr>
#       <th id="T_cd9e3_level0_row0" class="row_heading level0 row0" >APHRO</th>
#       <td id="T_cd9e3_row0_col0" class="data row0 col0" >0.03</td>
# ...

# %% [markdown]
# # AM

# %%
tp_datasets = {}
stats_datasets = {}

periods = {'APHRO': '1951-2005',
          'GPCP': '1891-2019',
          'CRU': '1901-2020',
          'CHIRPS': '1981-2024',
          'HARv2': '1980-2023',
          'ERA5': '1960-2025'}

path = '/bettik/PROJECTS/pr-regional-climate/bricej/results/timeseries/'

for model in models:
    tp_datasets[model] = {}
    stats_datasets[model] = {}
    for domain in domains:
        tp_datasets[model][domain] = pd.read_csv(path + f'timeseries_tp_AM_{domain}_{periods[model]}_{model}.csv')
        stats_datasets[model][domain] = pd.read_csv(path + f'stats_tp_AM_{domain}_{periods[model]}_{model}.csv')

# %%
resolutions = {'APHRO': '0.25°x0.25°',
               'GPCP': '1.0°x1.0°',
               'CRU': '0.5°x0.5°',
               'CHIRPS': '0.05°x0.05°',
               'HARv2': '10kmx10km',
               'ERA5': '0.25°x0.25°'}

#============== tableau des p-values ==========================

table = pd.DataFrame(index=models, columns=domains)
pvals = pd.DataFrame(index=models, columns=domains)

for model in models:
    for dom in domains:

        df = stats_datasets[model][dom]

        slope = df.loc[df['stat']=='slope','value'].values[0] * 10
        pval  = df.loc[df['stat']=='p_value','value'].values[0]

        table.loc[model, dom] = slope
        pvals.loc[model, dom] = pval

def bold_sig(val, p):
    if p < 0.05:
        return 'font-weight: bold'
    return ''

styled_table = table.style.apply(
    lambda x: [bold_sig(v, pvals.loc[x.name, col]) for col, v in x.items()],
    axis=1
).format("{:.2f}")

display(styled_table)

# ====================== plot time series ========================

fig, axes = plt.subplots(3, 2, figsize=(16,14))
axes = axes.flatten()

for i, dom in enumerate(domains):

    ax = axes[i]

    for model in models:
        da = tp_datasets[model][dom]
        ax.plot(da['year'], da['tp'], linestyle='-', label=f'{model} ({resolutions[model]}) ({periods[model]})', linewidth=1.5)

    ax.set_title(dom, fontsize=16, weight="bold")
    
    if i in [0, 2, 4]:  # colonne gauche
        ax.set_ylabel('tp (mm month⁻¹)', fontsize=12)
    if i in [4, 5]:  # ligne du bas
        ax.tick_params(labelbottom=True)
    if i in [0,1,2,3]:
        ax.tick_params(labelbottom=False)
    
    ax.grid(True, linestyle='--', alpha=0.5)

handles, labels = axes[0].get_legend_handles_labels()
fig.legend(
    handles,
    labels,
    loc='lower center',
    bbox_to_anchor=(0.5, -0.04),
    ncol=3,
    fontsize=16,
    frameon=True
)
fig.suptitle(f'AM Time series Precipitation', fontsize=16, weight='bold')

plt.tight_layout(rect=[0,0.05,1,1])
plt.show()
# Out:
# <style type="text/css">
# #T_be20e_row0_col4, #T_be20e_row1_col3, #T_be20e_row2_col2, #T_be20e_row2_col3, #T_be20e_row3_col3, #T_be20e_row4_col3, #T_be20e_row5_col1, #T_be20e_row5_col3, #T_be20e_row5_col4, #T_be20e_row5_col5 {
#   font-weight: bold;
# }
# </style>
# <table id="T_be20e">
#   <thead>
#     <tr>
#       <th class="blank level0" >&nbsp;</th>
#       <th id="T_be20e_level0_col0" class="col_heading level0 col0" >HMA</th>
#       <th id="T_be20e_level0_col1" class="col_heading level0 col1" >HK</th>
#       <th id="T_be20e_level0_col2" class="col_heading level0 col2" >SL</th>
#       <th id="T_be20e_level0_col3" class="col_heading level0 col3" >TP</th>
#       <th id="T_be20e_level0_col4" class="col_heading level0 col4" >CH</th>
#       <th id="T_be20e_level0_col5" class="col_heading level0 col5" >SEH</th>
#     </tr>
#   </thead>
#   <tbody>
#     <tr>
#       <th id="T_be20e_level0_row0" class="row_heading level0 row0" >APHRO</th>
# ...

# %% [markdown]
# # JJAS

# %%
tp_datasets = {}
stats_datasets = {}

periods = {'APHRO': '1951-2005',
          'GPCP': '1891-2019',
          'CRU': '1901-2020',
          'CHIRPS': '1981-2024',
          'HARv2': '1980-2023',
          'ERA5': '1960-2025'}

path = '/bettik/PROJECTS/pr-regional-climate/bricej/results/timeseries/'

for model in models:
    tp_datasets[model] = {}
    stats_datasets[model] = {}
    for domain in domains:
        tp_datasets[model][domain] = pd.read_csv(path + f'timeseries_tp_JJAS_{domain}_{periods[model]}_{model}.csv')
        stats_datasets[model][domain] = pd.read_csv(path + f'stats_tp_JJAS_{domain}_{periods[model]}_{model}.csv')

# %%
resolutions = {'APHRO': '0.25°x0.25°',
               'GPCP': '1.0°x1.0°',
               'CRU': '0.5°x0.5°',
               'CHIRPS': '0.05°x0.05°',
               'HARv2': '10kmx10km',
               'ERA5': '0.25°x0.25°'}

#============== tableau des p-values ==========================

table = pd.DataFrame(index=models, columns=domains)
pvals = pd.DataFrame(index=models, columns=domains)

for model in models:
    for dom in domains:

        df = stats_datasets[model][dom]

        slope = df.loc[df['stat']=='slope','value'].values[0] * 10
        pval  = df.loc[df['stat']=='p_value','value'].values[0]

        table.loc[model, dom] = slope
        pvals.loc[model, dom] = pval

def bold_sig(val, p):
    if p < 0.05:
        return 'font-weight: bold'
    return ''

styled_table = table.style.apply(
    lambda x: [bold_sig(v, pvals.loc[x.name, col]) for col, v in x.items()],
    axis=1
).format("{:.2f}")

display(styled_table)

# ====================== plot time series ========================

fig, axes = plt.subplots(3, 2, figsize=(16,14))
axes = axes.flatten()

for i, dom in enumerate(domains):

    ax = axes[i]

    for model in models:
        da = tp_datasets[model][dom]
        ax.plot(da['year'], da['tp'], linestyle='-', label=f'{model} ({resolutions[model]}) ({periods[model]})', linewidth=1.5)

    ax.set_title(dom, fontsize=16, weight="bold")
    
    if i in [0, 2, 4]:  # colonne gauche
        ax.set_ylabel('tp (mm month⁻¹)', fontsize=12)
    if i in [4, 5]:  # ligne du bas
        ax.tick_params(labelbottom=True)
    if i in [0,1,2,3]:
        ax.tick_params(labelbottom=False)
    
    ax.grid(True, linestyle='--', alpha=0.5)

handles, labels = axes[0].get_legend_handles_labels()
fig.legend(
    handles,
    labels,
    loc='lower center',
    bbox_to_anchor=(0.5, -0.04),
    ncol=3,
    fontsize=16,
    frameon=True
)
fig.suptitle(f'JJAS Time series Precipitation', fontsize=16, weight='bold')

plt.tight_layout(rect=[0,0.05,1,1])
plt.show()
# Out:
# <style type="text/css">
# #T_6125b_row0_col1, #T_6125b_row0_col2, #T_6125b_row1_col3, #T_6125b_row1_col4, #T_6125b_row2_col0, #T_6125b_row2_col1, #T_6125b_row2_col3, #T_6125b_row2_col4, #T_6125b_row2_col5, #T_6125b_row3_col0, #T_6125b_row3_col1, #T_6125b_row3_col3, #T_6125b_row4_col3, #T_6125b_row5_col1, #T_6125b_row5_col3, #T_6125b_row5_col5 {
#   font-weight: bold;
# }
# </style>
# <table id="T_6125b">
#   <thead>
#     <tr>
#       <th class="blank level0" >&nbsp;</th>
#       <th id="T_6125b_level0_col0" class="col_heading level0 col0" >HMA</th>
#       <th id="T_6125b_level0_col1" class="col_heading level0 col1" >HK</th>
#       <th id="T_6125b_level0_col2" class="col_heading level0 col2" >SL</th>
#       <th id="T_6125b_level0_col3" class="col_heading level0 col3" >TP</th>
#       <th id="T_6125b_level0_col4" class="col_heading level0 col4" >CH</th>
#       <th id="T_6125b_level0_col5" class="col_heading level0 col5" >SEH</th>
#     </tr>
#   </thead>
#   <tbody>
#     <tr>
# ...

# %% [markdown]
# # ON

# %%
tp_datasets = {}
stats_datasets = {}

periods = {'APHRO': '1951-2005',
          'GPCP': '1891-2019',
          'CRU': '1901-2020',
          'CHIRPS': '1981-2024',
          'HARv2': '1980-2023',
          'ERA5': '1960-2025'}

path = '/bettik/PROJECTS/pr-regional-climate/bricej/results/timeseries/'

for model in models:
    tp_datasets[model] = {}
    stats_datasets[model] = {}
    for domain in domains:
        tp_datasets[model][domain] = pd.read_csv(path + f'timeseries_tp_ON_{domain}_{periods[model]}_{model}.csv')
        stats_datasets[model][domain] = pd.read_csv(path + f'stats_tp_ON_{domain}_{periods[model]}_{model}.csv')

# %%
resolutions = {'APHRO': '0.25°x0.25°',
               'GPCP': '1.0°x1.0°',
               'CRU': '0.5°x0.5°',
               'CHIRPS': '0.05°x0.05°',
               'HARv2': '10kmx10km',
               'ERA5': '0.25°x0.25°'}

#============== tableau des p-values ==========================

table = pd.DataFrame(index=models, columns=domains)
pvals = pd.DataFrame(index=models, columns=domains)

for model in models:
    for dom in domains:

        df = stats_datasets[model][dom]

        slope = df.loc[df['stat']=='slope','value'].values[0] * 10
        pval  = df.loc[df['stat']=='p_value','value'].values[0]

        table.loc[model, dom] = slope
        pvals.loc[model, dom] = pval

def bold_sig(val, p):
    if p < 0.05:
        return 'font-weight: bold'
    return ''

styled_table = table.style.apply(
    lambda x: [bold_sig(v, pvals.loc[x.name, col]) for col, v in x.items()],
    axis=1
).format("{:.2f}")

display(styled_table)

# ====================== plot time series ========================

fig, axes = plt.subplots(3, 2, figsize=(16,14))
axes = axes.flatten()

for i, dom in enumerate(domains):

    ax = axes[i]

    for model in models:
        da = tp_datasets[model][dom]
        ax.plot(da['year'], da['tp'], linestyle='-', label=f'{model} ({resolutions[model]}) ({periods[model]})', linewidth=1.5)

    ax.set_title(dom, fontsize=16, weight="bold")
    
    if i in [0, 2, 4]:  # colonne gauche
        ax.set_ylabel('tp (mm month⁻¹)', fontsize=12)
    if i in [4, 5]:  # ligne du bas
        ax.tick_params(labelbottom=True)
    if i in [0,1,2,3]:
        ax.tick_params(labelbottom=False)
    
    ax.grid(True, linestyle='--', alpha=0.5)

handles, labels = axes[0].get_legend_handles_labels()
fig.legend(
    handles,
    labels,
    loc='lower center',
    bbox_to_anchor=(0.5, -0.04),
    ncol=3,
    fontsize=16,
    frameon=True
)
fig.suptitle(f'ON Time series Precipitation', fontsize=16, weight='bold')

plt.tight_layout(rect=[0,0.05,1,1])
plt.show()
# Out:
# <style type="text/css">
# #T_b54b9_row0_col2, #T_b54b9_row1_col1, #T_b54b9_row1_col5, #T_b54b9_row2_col1, #T_b54b9_row3_col0, #T_b54b9_row3_col3, #T_b54b9_row5_col3, #T_b54b9_row5_col5 {
#   font-weight: bold;
# }
# </style>
# <table id="T_b54b9">
#   <thead>
#     <tr>
#       <th class="blank level0" >&nbsp;</th>
#       <th id="T_b54b9_level0_col0" class="col_heading level0 col0" >HMA</th>
#       <th id="T_b54b9_level0_col1" class="col_heading level0 col1" >HK</th>
#       <th id="T_b54b9_level0_col2" class="col_heading level0 col2" >SL</th>
#       <th id="T_b54b9_level0_col3" class="col_heading level0 col3" >TP</th>
#       <th id="T_b54b9_level0_col4" class="col_heading level0 col4" >CH</th>
#       <th id="T_b54b9_level0_col5" class="col_heading level0 col5" >SEH</th>
#     </tr>
#   </thead>
#   <tbody>
#     <tr>
#       <th id="T_b54b9_level0_row0" class="row_heading level0 row0" >APHRO</th>
#       <td id="T_b54b9_row0_col0" class="data row0 col0" >-0.49</td>
# ...
